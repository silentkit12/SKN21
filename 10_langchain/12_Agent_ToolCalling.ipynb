# %% [markdown]
# # Agent 개요
# > **Agent는 대형 언어 모델을 두뇌로 사용하여, 목표를 스스로 이해하고 외부 도구와 상호작용하며 실제 작업을 자율적으로 수행하는 지능형 인공지능 시스템이다.**
#
# - Agent는 **대형 언어 모델(LLM, Large Language Model)과 다양한 도구(Tool)를 결합하여, 사용자의 복잡한 요청을 스스로 분석하고 처리하도록 설계된 지능형 인공지능 시스템이다.**
# 기존의 단순한 챗봇이 “질문 → 답변” 구조로 동작한다면,
#   - Agent는 **목표 설정 → 판단 → 실행 → 결과 반영**의 전 과정을 스스로 수행하는 구조를 가진다.
#
# - Agent는 주어진 목표를 달성하기 위해 자율적으로 **외부 환경(도구, API, 데이터베이스, 파일 시스템 등)과 상호작용하며 의사 결정을 내리고 실제 행동을 수행한다.**
# 이때 Agent의 **핵심적인 의사 결정과 추론 과정은 대형 언어 모델(LLM)이 담당**하며, **사람의 개입은 최소화**한다.
#
# - 즉, Agent는 단순히 정보를 말해주는 존재가 아니라, **"문제를 이해하고, 해결 방법을 계획하고, 직접 실행까지 담당하는 인공지능 작업 수행자"이다.**
#
# - AI 시스템을 구현할 때, **워크플로우**(**Workflow**)는 사전에 정의된 절차에 따라 실행 단계가 고정적인 구현 방식이라면, **에이전트**(**Agent**)는 주어진 목표를 달성하기 위해 스스로 계획을 수립하고, 상황을 판단하여 행동을 결정·실행하는 자율적인 방식이다.
#
#
#
# ## Agent의 주요 특징
#
# 1. **자율성** (Autonomy)
#    - Agent는 **사전 정의된 규칙**(Rule-based)에 의존하지 않고, LLM을 통해 현재 상황을 인지하고 추론하여 스스로 결정을 내리고 다음 행동을 계획할 수 있다.
#    - 즉, 사용자가 일일이 수행 단계를 지시하지 않아도, Agent는 **현재 상황을 해석하고 다음 행동을 동적으로 결정한다.**
#
# 2. **목표 지향성** (Goal-Oriented)
#     - Agent는 단순히 질문에 답변하는 **단순한 대화 상대가 아니라, 특정 목표와 복잡한 작업을 달성하기 위해 설계된 시스템**으로 최종 목표에 도달할 때 까지 반복적으로 행동한다.
#     - Agent는 어떤 처리를 할 때 항상 **"이 행동이 목표 달성에 도움이 되는가"를 기준**으로 판단한다.
#
# 3. **도구 활용** (Tool Utilization)
#     - Agent는 대형 언어 모델의 언어 이해 능력, 사전 학습 정보에만 의존하지 않고, 다양한 **외부 도구와 API를 함께 활용하여 실제 작업을 수행**한다.
#     - 이를 통해 LLM이 처리할 수없는 **최신 정보 검색, 복잡한 계산, 외부 시스템 제어**등과 같은 작업이 가능하다. 이를 통해 Agent는 **"말만 하는 AI"가 아니라 "실제로 일을 처리하는 AI"로 기능한다.**
#
# 4. **인간 개입 최소화** (Human-in-the-loop 최소화)
#     - Agent는 **문제 분석, 의사 결정, 행동 실행의 대부분을 스스로 결정하고 수행하도록 설계된다.**
#     - 사람은 **초기 목표 제시, 결과 확인 및 실행 최종 승인** 정도에 만 개입한다.

# %% [markdown]
# ## 다양한 Agent 활용 사례
#
# - **미국 국세청(IRS) 세무처리에 도입된 AI 에이전트**
#     - 미국 국세청(IRS)은 Salesforce Agentforce 기반 AI 에이전트를 도입해 세무 업무에서의 보조·분석 기능을 강화하고 업무 효율을 높이고 있다.
#
# -  **고객 추천 및 개인화된 콘텐츠 제공**
#     - Netflix, Amazon 같은 OTT 플랫폼은 사용자의 취향 변화에 따라 추천 시스템을 적응시키는 학습형 에이전트를 활용해 콘텐츠/제품 추천을 개선해 나간다.
#
# - **영업 지원용 AI 에이전트**
#     - Oracle은 영업 전문가를 위한 AI 에이전트를 도입해 고객 미팅 후 CRM 업데이트, 고객 데이터 분석·보고서 생성 같은 반복 작업을 자동화하고 있다.
#
# - **물류 최적화 및 배송 계획**
#     - Uber Freight, J.B. Hunt 등에서는 AI 에이전트를 활용해 실시간 교통·날씨 데이터 분석을 통해 가장 효율적인 배송 경로를 계산한다.
#
# - **AWS의 클라우드 자동화 에이전트**
#     - Amazon Web Services는 보안, DevOps, 일반 작업을 자동화하는 AI 에이전트들을 출시하며 클라우드 인프라 운영과 보안 모니터링을 강화하고 있다.
#
# - **삼성SDS AI 에이전트 플랫폼**
#     - 삼성SDS는 **사용자 개입 없이 스스로 판단·문제 해결이 가능한 AI 에이전트 플랫폼 ‘패브릭스(Fabrics)’**를 공개했다. 이를 통해 기업 내부에서 자동화된 의사결정과 작업 실행을 지원한다.

# %% [markdown]
# # ReAct 패턴
# - Agent 구현의 바탕이 되는 이론.
#
# ## 1. 개요
#
# ReAct는 **Reasoning**(추론)과 **Acting**(행동)을 결합한 AI Agent의 프롬프팅 패턴이다. 대형 언어 모델(LLM)이 단순히 답변을 생성하는 것이 아니라, 문제를 분석하고(Reasoning)하고 그에 따라 필요한 도구를 선택하여 실행하며(Acting), 결과를 관찰하고(Observation) 다음 추론에 반영하는 과정을 반복하면서 문제를 해결하는  Agent 설계 방식이다.
#
# ### ReAct의 핵심 개념
#
# 전통적인 프롬프팅 방식은 질문에 대해 즉시 답변을 생성한다. 하지만 **ReAct 패턴**은 다음과 같은 순환 구조를 따른다:
#
# ```
# 질문 → 생각(Thought) → 행동(Action) → 관찰(Observation) → 생각 → 행동 →  관찰 → ... → 답변
# ```
#
# - 예)
#   - 질문: "현재 서울의 날씨와 미세먼지 농도를 알려줘":
#
#     - **Thought(생각)**: 날씨 정보를 얻기 위해 날씨 API를 호출해야겠다
#     - **Action(행동)**: WeatherAPI.get_weather("서울")
#     - **Observation(관찰)**: 기온 15도, 맑음
#     - **Thought(생각)**: 이제 미세먼지 정보도 필요하다
#     - **Action(행동)**: AirQualityAPI.get_pm("서울")
#     - **Observation(관찰)**: PM10 농도 20㎍/㎥, 좋음
#     - **Answer(답변)**: 서울의 현재 날씨는 기온 15도로 맑고, 미세먼지 농도는 30㎍/㎥로 좋은 상태이다
#
# 이처럼 ReAct는 Agent가 **사고 과정을 명시적으로 드러내면서** 외부 도구를 활용하여 복잡한 문제를 해결할 수 있도록 한다.
#
# ### ReAct의 장점
#
# 1. **투명성**: Agent의 사고 과정을 추적할 수 있어 디버깅이 용이하다
# 2. **정확성**: 외부 지식과 도구를 활용하여 환각(hallucination)을 줄인다
# 3. **유연성**: 다양한 도구를 조합하여 복잡한 작업을 수행할 수 있다
# 4. **해석 가능성**: 각 단계의 추론 과정을 이해할 수 있다

# %% [markdown]
# ## 동작 단계
# ReAct 패턴은 크게 **5단계**의 순환 구조로 동작한다.
#
# 1. **질문 입력** (Question)
#      - 사용자로부터 해결해야 할 질문이나 작업을 입력받는다.
#      - 예시
#     ```bash
#      User Input: "2024년 노벨 물리학상 수상자는 누구이고, 그들의 주요 업적은 무엇인가?"
#     ```
#
# 2. **사고 단계** (Thought)
#      - 언어 모델이 사용자의 질문(요청)을 분석하고, 문제 해결을 위해 다음에 무엇을 해야 할지 추론한다.(계획을 세운다.)
#      - 이 단계에서 Agent는:
#          - 문제를 이해하고 분해한다
#          - 필요한 정보가 무엇인지 파악한다
#          - 어떤 도구를 사용해야 할지 결정한다
#          - 충분한 정보가 모였는지 판단한다
#
#        ```bash
#        Thought: 2024년 노벨 물리학상 정보는 내 학습 데이터에 없을 수 있다. 최신 정보를 검색해야 한다.
#        ```
#
# 3. **행동 단계** (Action)
#      - 사고 단계에서 결정된 계획을 바탕으로 실제 행동을 실행한다. 행동은 일반적으로 외부 도구(Tool) 호출한다.
#
#         ```bash
#         Action: 검색엔진.검색("2024 노벨 물리학상 수상자")
#         ```
#
# 4. **관찰 단계** (Observation)
#      - 행동(Acttion)의 결과를 관찰하고 얻은 정보를 확인한다.
#
#        ```bash
#        Observation: 2024년 노벨 물리학상은 John Hopfield와 Geoffrey Hinton에게 수여되었다.
#        ```
#
#  5. **반복 또는 종료**
#        - 관찰한 정보가 사용자 질문에 대한 답변을 하는데 충분하지 않다면 2번의 사고 단계로 돌아가 추가 행동을 계획한다.(사고→행동→관찰 반복)
#        - 충분한 정보가 모였다면 그 정보를 바탕으로 최종 답변을 생성한다.
#
#           ```bash
#           Thought: 수상자 이름은 알았지만 구체적인 업적 내용이 필요하다.
#
#           Action: Search("John Hopfield Geoffrey Hinton 노벨상 업적")
#
#           Observation: Hopfield는 연상 메모리를 위한 Hopfield 네트워크를 개발했고, Hinton은 딥러닝의 역전파 알고리즘과 볼츠만 머신을 연구했다.
#
#           Thought: 이제 질문에 답할 충분한 정보가 모였다.
#
#           Action: Finish("2024년 노벨 물리학상은 John Hopfield와 Geoffrey Hinton에게 수여되었다. Hopfield는 연상 메모리를 위한 Hopfield 네트워크를 개발했고, Hinton은 딥러닝의 역전파 알고리즘과 볼츠만 머신 연구로 인공신경망 발전에 기여했다.")
#           ```
#
# ### 동작 흐름도
# ![ReAct](figures/agent-ReAct.png)

# %% [markdown]
# # TOOL
# - **Tool은 하나의 기능을 처리하는 함수이다.**
#     - Tool은 하나의 명확한 기능을 수행하도록 정의된 함수(Function) 형태의 외부 실행 수단이다.
#     - 대형 언어 모델(LLM)은 본래 텍스트를 생성하는 모델이므로, 실제 계산, 검색, 파일 처리, 데이터베이스 조회와 같은 현실 세계의 작업을 직접 수행할 수는 없다. 이런 실제 작업을 대신 수행하는 단위가 Tool 이다.
# - **AI Model은 Tool을 이용해 자체 지식의 한계(Knowlege cutoff)를 넘어서는 정보를 제공할 수 있다.**
# > **Knowledge Cutoff**:
# > - Knowledge cutoff는 AI 모델이 학습한 데이터가 마지막으로 업데이트된 시점을 의미하며, 그 이후에 발생한 정보나 사건에 대해서는 AI 모델이 학습한 지식으로는 알지 못하는 한계를 가지게 된다.
#
# ## Tool Calling 개요
# - **도구 호출**(Tool Calling)은 LLM이 자체적으로 수행할 수 없는 작업을 외부 도구나 API를 활용하여 처리할 수 있게 하는 핵심 기능이다. 이를 통해 **LLM은 자체 지식의 한계를 넘어서는 최신 정보, 정확한 계산, 외부 시스템 제어 등의 능력을 확보**할 수 있다.
#
# - **도구 호출(Tool Calling)의 3단계**
#     1. 도구 바인딩 (Tool Binding): **LLM에 사용가능한 tool들을 등록한다.**
#         - LLM에게 사용 가능한 도구 목록과 각 도구의 기능(설명) 및 필요한 입력 매개변수를 미리 정의하여 제공한다.
#             - Tool 함수
#             - Tool 이름
#             - Tool이 수행하는 기능 설명
#             - 입력 파라미터 type과 설명
#     2. **사용자 질의가 들어오면 LLM이 도구 사용 여부를 판단**한다.
#         - LLM 자체 추론으로 해결가능한 문제인지 Tool을 호출해야 처리할 수있는 문제 인지를 확인한다.
#         - **Tool 사용이 필요한 문제** 라고 판단하면
#           - 도구를 호출 하는 것이 아니라 어떻게 호출해야 하는지 요청정보를 생성한다.
#             - 어떤 Tool을 사용해야 하는지, 그 Tool에 어떤 값을 전달해야하는지를 응답으로 생성한다.
#     3.  **시스템이 Tool 호출 요청정보에 따라 Tool을 실행하고 그 결과를 LLM 에게 전달**한다.
#
#      ![toolcalling_concept](figures/toolcalling_concept.png)
#
# - **TOOL Calling 예**
#     - LLM이 수학 계산을 수행해야 할 때, 직접 계산하는 대신 미리 정의된 '계산' 도구를 호출하여 정확한 결과를 얻을 수 있다.
#   	- LLM에 최신 정보를 요청하는 질문이 들어왔을 때 '검색' 도구나 'Database 연동' 도구를 사용해 최신 뉴스를 검색하거나, 특정 데이터베이스에서 정보를 조회하는 등의 작업을 수행할 수 있다.
#   	- LLM 이 작성한 결과를 google docs와 같은 문서도구나 SNS에 등록한다.
#
# ## Langchain 과 Tool calling
# - Tool calling은 대부분의 LLM 서비스가 지원한다.
#   - [Tool Calling을 지원하는 LLM 모델](https://docs.langchain.com/oss/python/integrations/chat)만 사용할 수 있다.
# - LangChain은 다양한 모델들의 도구 호출 방식을 표준화하여 일관된 인터페이스로 제공한다. 이를 통해 개발자들은 다양한 모델과 도구들을 쉽게 통합할 수있다.
#   - [Langchain Tool Calling Concept](https://docs.langchain.com/oss/python/langchain/tools)
# - Langchain 제공 Built-in tools
#     -  https://docs.langchain.com/oss/python/integrations/tools

# %% [markdown]
# # LangChain Built-in Tools 사용으로 Tool Calling 이해
#
# - Langchain은 다양한 도구들을 미리 구현해서 제공하고 있다. 이것들을 builtin tool이라고 한다.
#   - [Langchain 지원 Built tools](https://docs.langchain.com/oss/python/integrations/tools)
# - Built-In tool 뿐만 아니라 사용자 정의 Tool들을 직접 구현할 수있는 방법도 제공한다.
#
# ## Tavily API 검색 Tool
# > Tavily 웹 검색 도구 사용해 Tool calling을 이해한다.
# - **Tavily** Service: AI을 위한 웹 검색 API Service.
# - https://tavily.com/
# -  LLM과 RAG 시스템에 최적화된 검색 엔진.
#    -  기존의 일반 검색 엔진들과 달리, Tavily는 AI 애플리케이션의 요구사항에 맞춰 설계되었다.
#    -  Tavily는 최대 20개 이상의 신뢰도 높은 웹사이트에서 관련정보를 수집한다.
#    -  수집된 데이터는 AI가 관련성, 신뢰도, 최신성 등을 기준으로 평가해 가장 적합한 정보만 선별해서 요약한다.
#    -  최종적으로 이 정보는 LLM이 바로 활용할 수있도록 컨텐츠 스티펫, 요약, 출처 등의 구조화된 형태로 반환한다.
#    -  월 1000회 무료 사용 가능.
# - **Tavily API Key 받기**
#   - 회원가입 후 로그인 한다.
#   - Overview 화면에서 API Key 생성
#     - default API key 사용할 수있다.
#   - 환경변수에 등록한다.
#       - 변수이름: `TAVILY_API_KEY`
#
# ### TavilySearch
# - Langchain에서 제공하는 tool로 Tavily 의 검색 엔진 API를 사용해 검색을 수행한다.
# - 설치
#   - `pip install langchain-tavily`
# - https://python.langchain.com/docs/integrations/tools/tavily_search/

# %%
# !uv pip install langchain-tavily
# Out:
# Resolved 41 packages in 463ms
# Prepared 1 package in 77ms
# Installed 1 package in 32ms
#  + langchain-tavily==0.2.16

# %%
from dotenv import load_dotenv
from langchain_tavily import TavilySearch #Tavily 검색 tool

load_dotenv()
# Out:
# c:\Users\USER\Documents\SKN21\10_langchain\.venv\Lib\site-packages\langchain_tavily\tavily_research.py:97: UserWarning: Field name "output_schema" in "TavilyResearch" shadows an attribute in parent "BaseTool"
#   class TavilyResearch(BaseTool):  # type: ignore[override, override]
# c:\Users\USER\Documents\SKN21\10_langchain\.venv\Lib\site-packages\langchain_tavily\tavily_research.py:97: UserWarning: Field name "stream" in "TavilyResearch" shadows an attribute in parent "BaseTool"
#   class TavilyResearch(BaseTool):  # type: ignore[override, override]
# True

# %%
# 객체 생성 - 검색 옵션을 파라미터로 설정.

tavily_search = TavilySearch(
    max_results=3, # 최대 검색 개수
    # include_raw_content=True, # 원본 내용도 포함
    # include_answer=True, # 검색 결과를 바탕으로 Tavily AI가 종합적 답변을 하도록 한다.
    # include_images=True # 검색한 문서 내의 이미지(경로)들을 반환
    # time_range="year", # day, week, month, year - 현재 시점 기준으로 지정한 기간 내의 문서들만 검색결과로 제공.
)

#검색
query = "2025년 한국시리즈 우승팀은?"
# result = tavily_search.invoke(query)
result = tavily_search.invoke(
    {
        "query":query,
        "include_images":True #옵션들을 Key value로 설정 해서  실행시 동적으로 설정.
    }
)

# %%
print(type(result))
result
# Out:
# <class 'dict'>
# {'query': '2025년 한국시리즈 우승팀은?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': ['https://blogthumb.pstatic.net/MjAyNTAzMjNfNjYg/MDAxNzQyNzE4ODAxNzkw.oSUS641rn-u5mmRK9X90k3cOu6mV_S-lXEroFC41xc0g.ifwCdPWPHpTasTUsv1lLbaYgl6z8MXOE4Ezbpu0y2WUg.PNG/������-�Է����ּ���__���纻-_27_-001.png?type=w2',
#   'https://www.sportschosun.com/article/html/2025/10/22/2025102301001362100180743_w.jpg',
#   'https://img.etoday.co.kr/pto_db/2024/10/20241029063224_2094589_999_567.jpg',
#   'https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEhIwYdP22bQ2HL4mmF0rsT9O2cpYw8iRkBY4AkpbjujNUkhyphenhyphen-k1BICpkEpj1u1EejbsLIaOld7q40ZSmna-vLCXKj1XNTr8rRHDAB1QhsT-BNRjZkZGPzqPDGc501RlSJyXAx7_HJX2KDCcpZtRWBiUFWbOy6x-MVWIYlHTxsNi6iKnX7ZMjJzvPu6q38jK/s1024/ChatGPT+Image+2025년+10월+11일+오전+11_20_52.png',
#   'https://blog.kakaocdn.net/dn/boRtrn/btsMgUfWOwB/t7Xx4EoLVFU5OrsilmFCmK/img.jpg'],
#  'results': [{'url': 'https://ko.wikipedia.org/wiki/2025%EB%85%84_%ED%95%9C%EA%B5%AD%EC%8B%9C%EB%A6%AC%EC%A6%88',
#    'title': '2025년 한국시리즈',
#    'content': '| 10월 30일(목) | 4차전 | **LG 트윈스** | **7** - 4 | 한화 이글스 | 16,750명 **(매진)** | 김현수 "김현수 (1988년생 야구 선수)") (LG 트윈스) |. | 우승\xa0: LG 트윈스 (4번째), 한국시리즈 MVP\xa0: 김현수 "김현수 (1988년생 야구 선수)") (LG 트윈스) |. 한화가 6회초 1사 2루 상황에서 노시환의 적시타에 이어서 1사 1, 3루 상황에서 하주석의 희생플라이로 2점 추격을 해봤으나 LG는 6회말 공격 1사 만루 상황에서 신민재 "신민재 (1996년)")의 2타점 적시타, 2사 1, 2루에서 김현수 "김현수 (1988년생 야구 선수)")와 문보경의 연속 적시타로 4득점을 추가해 상대의 추격을 완전히 뿌리치며 사실상 승부를 결정지었다. 하지만 LG가 이후 폰세를 상대로 3회초 2사 1루 상황에서 터진 신민재 "신민재 (1996년)")의 1타점 2루타로 동점, 4회초에는 1아웃에서 앞선 2회말 실책을 만회한 김현수 "김현수 (야구 선수)")의 홈런으로 앞서간 가운데 팽팽한 1점 차 승부가 이어졌고 이후 LG는 8회초 1사 1, 3루 오스틴 타석에서 김서현 "김서현 (야구 선수)")이 폭투를 범하여 홍창기의 대주자로 들어온 3루 주자 최원영 "최원영 (야구 선수)")이 득점하며 3:1로 앞서며 LG의 흐름으로 3차전이 흐르고 있었으나 8회말 한화가 대반격을 시작했다.',
#    'score': 0.88822687,
#    'raw_content': None},
#   {'url': 'https://www.youtube.com/watch?v=MmcDtgJ1zqs',
#    'title': '[속보] LG 트윈스, 2025 한국시리즈 우승…2년만에 왕좌 탈환 ...',
#    'content': '프로야구 LG 트윈스가 한화 이글스를 꺾고 2025년 한국시리즈 우승을 차지했습니다. LG는 조금 전 대전에서 열린 한국시리즈 5차전에서 4대1로 승리,',
#    'score': 0.87706697,
#    'raw_content': None},
#   {'url': 'https://www.facebook.com/kbo1982/posts/2025-kbo-%ED%95%9C%EA%B5%AD%EC%8B%9C%EB%A6%AC%EC%A6%88-%EC%9A%B0%EC%8A%B9-lg%ED%8A%B8%EC%9C%88%EC%8A%A4%EC%9E%85%EB%8B%88%EB%8B%A41031-lg%ED%95%9C%ED%99%94%EC%95%BC%EA%B5%AC-baseball-kbo-%ED%8F%AC%EC%8A%A4%ED%8A%B8%EC%8B%9C%EC%A6%8C-%ED%95%9C%EA%B5%AD%EC%8B%9C%EB%A6%AC%EC%A6%88_5%EC%B0%A8%EC%A0%84-lg%ED%8A%B8%EC%9C%88%EC%8A%A4-%EC%9A%B0%EC%8A%B9-kbo2/1315789490588357/',
#    'title': '2025 KBO 한국시리즈 우승! LG트윈스입니다!(10.31. ...',
#    'content': '2025 KBO 한국시리즈 우승! LG트윈스입니다!(10.31. LG: 한화) #야구 #baseball #KBO #포스트시즌 #한국시리즈_5차전 #LG트윈스 #우승 #kbo20251031.',
#    'score': 0.86713725,
#    'raw_content': None}],
#  'response_time': 0.0,
#  'request_id': '57a18cc1-4ce6-45de-ac5f-556c4c0b9a61'}

# %%
# 도구 - 도구 이름, 도구 설명 ==> llm이 도구를 사용 여부를 판단하는 근거.
# Tavily(built-in)도구 정보를 확인

print("도구이름:", tavily_search.name)
print("도구설명:")
print(tavily_search.description)
# Out:
# 도구이름: tavily_search
# 도구설명:
# A search engine optimized for comprehensive, accurate, and trusted results. Useful for when you need to answer questions about current events. It not only retrieves URLs and snippets, but offers advanced search depths, domain management, time range filters, and image search, this tool delivers real-time, accurate, and citation-backed results.Input should be a search query.

# %%
schema = tavily_search.args_schema.model_json_schema()
schema
#도구 스키마(도구의 설계구조)
#도구 호출시 전달 파라미터 정보.
# Out:
# {'additionalProperties': True,
#  'description': 'Input for [TavilySearch]',
#  'properties': {'query': {'description': 'Search query to look up',
#    'title': 'Query',
#    'type': 'string'},
#   'include_domains': {'anyOf': [{'items': {'type': 'string'}, 'type': 'array'},
#     {'type': 'null'}],
#    'default': [],
#    'description': 'A list of domains to restrict search results to.\n\n        Use this parameter when:\n        1. The user explicitly requests information from specific websites (e.g., "Find climate data from nasa.gov")\n        2. The user mentions an organization or company without specifying the domain (e.g., "Find information about iPhones from Apple")\n\n        In both cases, you should determine the appropriate domains (e.g., ["nasa.gov"] or ["apple.com"]) and set this parameter.\n\n        Results will ONLY come from the specified domains - no other sources will be included.\n        Default is None (no domain restriction).\n        ',
#    'title': 'Include Domains'},
#   'exclude_domains': {'anyOf': [{'items': {'type': 'string'}, 'type': 'array'},
#     {'type': 'null'}],
#    'default': [],
#    'description': 'A list of domains to exclude from search results.\n\n        Use this parameter when:\n        1. The user explicitly requests to avoid certain websites (e.g., "Find information about climate change but not from twitter.com")\n        2. The user mentions not wanting results from specific organizations without naming the domain (e.g., "Find phone reviews but nothing from Apple")\n\n        In both cases, you should determine the appropriate domains to exclude (e.g., ["twitter.com"] or ["apple.com"]) and set this parameter.\n\n        Results will filter out all content from the specified domains.\n        Default is None (no domain exclusion).\n        ',
#    'title': 'Exclude Domains'},
#   'search_depth': {'anyOf': [{'enum': ['basic',
#       'advanced',
#       'fast',
#       'ultra-fast'],
#      'type': 'string'},
#     {'type': 'null'}],
#    'default': 'basic',
#    'description': 'Controls search thoroughness and result comprehensiveness.\n    \n        Use "basic" for simple queries requiring quick, straightforward answers.\n        \n        Use "advanced" for complex queries, specialized topics, \n        rare information, or when in-depth analysis is needed.\n        \n        Use "fast" for optimized low latency with high relevance.\n        \n        Use "ultra-fast" when latency is prioritized above all else.\n        ',
#    'title': 'Search Depth'},
#   'include_images': {'anyOf': [{'type': 'boolean'}, {'type': 'null'}],
#    'default': False,
#    'description': 'Determines if the search returns relevant images along with text results.\n   \n        Set to True when the user explicitly requests visuals or when images would \n        significantly enhance understanding (e.g., "Show me what black holes look like," \n        "Find pictures of Renaissance art").\n        \n        Leave as False (default) for most informational queries where text is sufficient.\n        ',
#    'title': 'Include Images'},
#   'time_range': {'anyOf': [{'enum': ['day', 'week', 'month', 'year'],
#      'type': 'string'},
#     {'type': 'null'}],
#    'default': None,
#    'description': 'Limits results to content published within a specific timeframe.\n        \n        ONLY set this when the user explicitly mentions a time period \n        (e.g., "latest AI news," "articles from last week").\n        \n        For less popular or niche topics, use broader time ranges \n        ("month" or "year") to ensure sufficient relevant results.\n   \n        Options: "day" (24h), "week" (7d), "month" (30d), "year" (365d).\n        \n        Default is None.\n        ',
#    'title': 'Time Range'},
#   'topic': {'anyOf': [{'enum': ['general', 'news', 'finance'],
#      'type': 'string'},
#     {'type': 'null'}],
#    'default': 'general',
#    'description': 'Specifies search category for optimized results.\n   \n        Use "general" (default) for most queries, INCLUDING those with terms like \n        "latest," "newest," or "recent" when referring to general information.\n\n        Use "finance" for markets, investments, economic data, or financial news.\n\n        Use "news" ONLY for politics, sports, or major current events covered by \n        mainstream media - NOT simply because a query asks for "new" information.\n        ',
#    'title': 'Topic'},
#   'start_date': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#    'default': None,
#    'description': 'Filters search results to include only content published on or after this date.\n        \n        Use this parameter when you need to:\n        - Find recent developments or updates on a topic\n        - Exclude outdated information from search results\n        - Focus on content within a specific timeframe\n        - Combine with end_date to create a custom date range\n        \n        Format must be YYYY-MM-DD (e.g., "2024-01-15" for January 15, 2024).\n        \n        Examples:\n        - "2024-01-01" - Results from January 1, 2024 onwards\n        - "2023-12-25" - Results from December 25, 2023 onwards\n        \n        When combined with end_date, creates a precise date range filter.\n        \n        Default is None (no start date restriction).\n        ',
#    'title': 'Start Date'},
#   'end_date': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#    'default': None,
#    'description': 'Filters search results to include only content published on or before this date.\n        \n        Use this parameter when you need to:\n        - Exclude content published after a certain date\n        - Study historical information or past events\n        - Research how topics were covered during specific time periods\n        - Combine with start_date to create a custom date range\n        \n        Format must be YYYY-MM-DD (e.g., "2024-03-31" for March 31, 2024).\n        \n        Examples:\n        - "2024-03-31" - Results up to and including March 31, 2024\n        - "2023-12-31" - Results up to and including December 31, 2023\n        \n        When combined with start_date, creates a precise date range filter.\n        For example: start_date="2024-01-01", end_date="2024-03-31" \n        returns results from Q1 2024 only.\n        \n        Default is None (no end date restriction).\n        ',
#    'title': 'End Date'}},
#  'required': ['query'],
#  'title': 'TavilySearchInput',
#  'type': 'object'}

# %%
schema['properties']
# Out:
# {'query': {'description': 'Search query to look up',
#   'title': 'Query',
#   'type': 'string'},
#  'include_domains': {'anyOf': [{'items': {'type': 'string'}, 'type': 'array'},
#    {'type': 'null'}],
#   'default': [],
#   'description': 'A list of domains to restrict search results to.\n\n        Use this parameter when:\n        1. The user explicitly requests information from specific websites (e.g., "Find climate data from nasa.gov")\n        2. The user mentions an organization or company without specifying the domain (e.g., "Find information about iPhones from Apple")\n\n        In both cases, you should determine the appropriate domains (e.g., ["nasa.gov"] or ["apple.com"]) and set this parameter.\n\n        Results will ONLY come from the specified domains - no other sources will be included.\n        Default is None (no domain restriction).\n        ',
#   'title': 'Include Domains'},
#  'exclude_domains': {'anyOf': [{'items': {'type': 'string'}, 'type': 'array'},
#    {'type': 'null'}],
#   'default': [],
#   'description': 'A list of domains to exclude from search results.\n\n        Use this parameter when:\n        1. The user explicitly requests to avoid certain websites (e.g., "Find information about climate change but not from twitter.com")\n        2. The user mentions not wanting results from specific organizations without naming the domain (e.g., "Find phone reviews but nothing from Apple")\n\n        In both cases, you should determine the appropriate domains to exclude (e.g., ["twitter.com"] or ["apple.com"]) and set this parameter.\n\n        Results will filter out all content from the specified domains.\n        Default is None (no domain exclusion).\n        ',
#   'title': 'Exclude Domains'},
#  'search_depth': {'anyOf': [{'enum': ['basic',
#      'advanced',
#      'fast',
#      'ultra-fast'],
#     'type': 'string'},
#    {'type': 'null'}],
#   'default': 'basic',
#   'description': 'Controls search thoroughness and result comprehensiveness.\n    \n        Use "basic" for simple queries requiring quick, straightforward answers.\n        \n        Use "advanced" for complex queries, specialized topics, \n        rare information, or when in-depth analysis is needed.\n        \n        Use "fast" for optimized low latency with high relevance.\n        \n        Use "ultra-fast" when latency is prioritized above all else.\n        ',
#   'title': 'Search Depth'},
#  'include_images': {'anyOf': [{'type': 'boolean'}, {'type': 'null'}],
#   'default': False,
#   'description': 'Determines if the search returns relevant images along with text results.\n   \n        Set to True when the user explicitly requests visuals or when images would \n        significantly enhance understanding (e.g., "Show me what black holes look like," \n        "Find pictures of Renaissance art").\n        \n        Leave as False (default) for most informational queries where text is sufficient.\n        ',
#   'title': 'Include Images'},
#  'time_range': {'anyOf': [{'enum': ['day', 'week', 'month', 'year'],
#     'type': 'string'},
#    {'type': 'null'}],
#   'default': None,
#   'description': 'Limits results to content published within a specific timeframe.\n        \n        ONLY set this when the user explicitly mentions a time period \n        (e.g., "latest AI news," "articles from last week").\n        \n        For less popular or niche topics, use broader time ranges \n        ("month" or "year") to ensure sufficient relevant results.\n   \n        Options: "day" (24h), "week" (7d), "month" (30d), "year" (365d).\n        \n        Default is None.\n        ',
#   'title': 'Time Range'},
#  'topic': {'anyOf': [{'enum': ['general', 'news', 'finance'],
#     'type': 'string'},
#    {'type': 'null'}],
#   'default': 'general',
#   'description': 'Specifies search category for optimized results.\n   \n        Use "general" (default) for most queries, INCLUDING those with terms like \n        "latest," "newest," or "recent" when referring to general information.\n\n        Use "finance" for markets, investments, economic data, or financial news.\n\n        Use "news" ONLY for politics, sports, or major current events covered by \n        mainstream media - NOT simply because a query asks for "new" information.\n        ',
#   'title': 'Topic'},
#  'start_date': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#   'default': None,
#   'description': 'Filters search results to include only content published on or after this date.\n        \n        Use this parameter when you need to:\n        - Find recent developments or updates on a topic\n        - Exclude outdated information from search results\n        - Focus on content within a specific timeframe\n        - Combine with end_date to create a custom date range\n        \n        Format must be YYYY-MM-DD (e.g., "2024-01-15" for January 15, 2024).\n        \n        Examples:\n        - "2024-01-01" - Results from January 1, 2024 onwards\n        - "2023-12-25" - Results from December 25, 2023 onwards\n        \n        When combined with end_date, creates a precise date range filter.\n        \n        Default is None (no start date restriction).\n        ',
#   'title': 'Start Date'},
#  'end_date': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#   'default': None,
#   'description': 'Filters search results to include only content published on or before this date.\n        \n        Use this parameter when you need to:\n        - Exclude content published after a certain date\n        - Study historical information or past events\n        - Research how topics were covered during specific time periods\n        - Combine with start_date to create a custom date range\n        \n        Format must be YYYY-MM-DD (e.g., "2024-03-31" for March 31, 2024).\n        \n        Examples:\n        - "2024-03-31" - Results up to and including March 31, 2024\n        - "2023-12-31" - Results up to and including December 31, 2023\n        \n        When combined with start_date, creates a precise date range filter.\n        For example: start_date="2024-01-01", end_date="2024-03-31" \n        returns results from Q1 2024 only.\n        \n        Default is None (no end date restriction).\n        ',
#   'title': 'End Date'}}

# %% [markdown]
# ## LLM ToolCalling 흐름
#
# ### 1. Tool 생성 및 LLM Model에 tool binding
# - `LLM-Model.bind_tools(tools=[tool_1, tool_2, ...])`

# %%
from langchain_openai import ChatOpenAI
from langchain_tavily import TavilySearch

tavily_search = TavilySearch(max_results=5)
model = ChatOpenAI(model="gpt-5-mini") # 뇌 - > 성능 좋은 모델을 사용(판단자)
toolkit=[tavily_search] # 툴들 모음
# 모델에 tool들을 binding
tool_model = model.bind_tools(tools=toolkit)
print(type(tool_model), type(model))
# Out:
# <class 'langchain_core.runnables.base.RunnableBinding'> <class 'langchain_openai.chat_models.base.ChatOpenAI'>

# %%
# 모델 호출 결과로 사용자에게 응답을 할지, tool을 호출할지 결정
## tool_calls = [] 빈 리스트: 최종응답 (content="내용")
## tool_calls = [dict] : 비어있지 않으면 -> tool을 호출 (content="") < 비어있음.

# %%
# 질문에 따른 응답 차이
# tool이 필요없는 질문
# content = "답변내용"
# tool_calls=[] # 빈 리스트
result = tool_model.invoke("안녕하세요")

# %%
print(result.content) # llm의 응답
print(result.tool_calls)
# Out:
# 안녕하세요! 무엇을 도와드릴까요?
# []

# %%
## tool이 필요한 질문
# 답변 : content="", tool_calls=list[dictionary- 호출방식]
result2 = tool_model.invoke("2025년 12월 30일 서울 날씨는 어때?")

# %%
result2
# Out:
# AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 179, 'prompt_tokens': 1284, 'total_tokens': 1463, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CsOfxrquXtFbKNFxVNVHiniYUFY36', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b6e36-21e8-7bc1-b93f-798f49fa7f2f-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': '서울 날씨 2025-12-30 기상청', 'search_depth': 'fast', 'include_images': False, 'topic': 'general'}, 'id': 'call_m7DoiLf6KX4w77InByk0Z9ZG', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1284, 'output_tokens': 179, 'total_tokens': 1463, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})

# %%
vars(result2) # vars(객체)-> 객체 속성들을 dictionaly 로
print("응답메세지:", result2.content) # ""
print("tool calls", result2.tool_calls) # list[dict]
# Out:
# {'content': '',
#  'additional_kwargs': {'refusal': None},
#  'response_metadata': {'token_usage': {'completion_tokens': 179,
#    'prompt_tokens': 1284,
#    'total_tokens': 1463,
#    'completion_tokens_details': {'accepted_prediction_tokens': 0,
#     'audio_tokens': 0,
#     'reasoning_tokens': 128,
#     'rejected_prediction_tokens': 0},
#    'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}},
#   'model_provider': 'openai',
#   'model_name': 'gpt-5-mini-2025-08-07',
#   'system_fingerprint': None,
#   'id': 'chatcmpl-CsOfxrquXtFbKNFxVNVHiniYUFY36',
#   'service_tier': 'default',
#   'finish_reason': 'tool_calls',
#   'logprobs': None},
#  'type': 'ai',
#  'name': None,
#  'id': 'lc_run--019b6e36-21e8-7bc1-b93f-798f49fa7f2f-0',
#  'tool_calls': [{'name': 'tavily_search',
#    'args': {'query': '서울 날씨 2025-12-30 기상청',
#     'search_depth': 'fast',
#     'include_images': False,
#     'topic': 'general'},
#    'id': 'call_m7DoiLf6KX4w77InByk0Z9ZG',
#    'type': 'tool_call'}],
#  'invalid_tool_calls': [],
#  'usage_metadata': {'input_tokens': 1284,
#   'output_tokens': 179,
#   'total_tokens': 1463,
#   'input_token_details': {'audio': 0, 'cache_read': 0},
#   'output_token_details': {'audio': 0, 'reasoning': 128}}}

# %% [markdown]
# ### 2. Tool 호출
# - LLM 모델이 tool 요청을 결정한 경우 **어떤 tool을 어떻게 호출할 지** AIMessage의 `tool_calls` 속성에 넣어 반환한다.
# - `tool_calls` 의 호출 정보를 넣어 `tool.invoke()` 호출한다.
#    - `tool.invoke(result.tool_calls[0])`
#    - **반환타입**: `ToolMessage`
#      - Tool의 처리결과를 담는 Message Type 이다.

# %%
#LLM 응답 (AIMessage)에 tool_calls 가 있을 경우 Tool을 호출
#result2.tool_calls:list[dict] dict - 개별 tool 호출정보, list는 묶어주는 역할.

search_result = tavily_search.invoke(result2.tool_calls[0])
type(search_result)
# Out:
# langchain_core.messages.tool.ToolMessage

# %%
search_result
# Out:
# ToolMessage(content='{"query": "서울 날씨 2025-12-30 기상청", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.kmib.co.kr/article/view_amp.asp?arcid=0029179968", "title": "오늘의 날씨 - 오전 (2025년 12월 30일)", "content": "오늘의 날씨 - 오전 (2025년 12월 30일) - 국민일보\\n\\nImage 1: 국민일보\\n\\n\\n\\n 입력 2025-12-30 05:31\\n\\nImage 3\\n\\n12월 30일 화요일, 아침 날씨입니다.\\n\\n아침 최저기온은 서울 -3.0도, 인천 -4.0도, 수원 -4.0도, 춘천 -5.0도, 강릉 -2.0도, 청주 -4.0도, 대전 -5.0도, 전주 -3.0도, 광주 -1.0도, 대구 -1.0도, 부산 2.0도, 제주 6.0도로 예상됩니다.\\n\\n낮 최고기온은 서울 2.0도, 인천 2.0도, 수원 2.0도, 춘천 3.0도, 강릉 4.0도, 청주 3.0도, 대전 4.0도, 전주 5.0도, 광주 6.0도, 대구 6.0도, 부산 8.0도, 제주 8.0도로 예상됩니다.\\n\\n이상 날씨였습니다.\\n\\n웨더봇 기자\\n\\n※ 이 기사는 국민일보가 개발한 기상뉴스 전용 인공지능 로봇 ‘웨더봇’이 기상청 데이터를 토대로 작성한 것입니다. 지속적인 업그레이드를 통해 더욱 풍부한 내용과 정확한 문장을 담아 가겠습니다.", "score": 0.8893851, "raw_content": null}, {"url": "https://kosmos13.tistory.com/entry/서울-날씨-완전-정복-실시간-예보-확인부터-기온별-옷차림-미세먼지-대처법까지", "title": "서울 날씨 완전 정복: 실시간 예보 확인부터 기온별 옷차림, 미세먼지 대처법까지", "content": "본문 바로가기\\n\\n# 하하호호1\\n\\n카테고리 없음\\n\\n# 서울 날씨 완전 정복: 실시간 예보 확인부터 기온별 옷차림, 미세먼지 대처법까지\\n\\n by 코스모스 13 2025. 12. 22.\\n\\n반응형\\n\\n서울 날씨, 변덕스럽기로 유명하죠? 강남에는 비가 오는데 강북은 맑은 이유부터 기상청 레이더 활용법, 봄·여름·가을·겨울 계절별 여행 팁과 옷차림 가이드, 그리고 미세먼지 최악인 날의 생존 전략까지. 서울의 사계절을 스마트하게 즐기는 모든 노하우를 담았습니다.\\n\\n단순히 \\"오늘 서울 비 오나요?\\"를 넘어, 구별 날씨 차이(열섬 현상), 미세먼지 대처법, 기온별 옷차림 공식, 장마철과 한파 생존 전략, 그리고 서울 여행하기 가장 좋은 시기까지 서울의 하늘 아래서 살아가는 데 필요한 모든 정보를 집대성했습니다.\\n\\n― \\"천만 시민의 하루를 결정하는 하늘\\" 서울의 4계절을 읽는 법", "score": 0.59655124, "raw_content": null}, {"url": "https://rtonblog.com/%EC%84%9C%EC%9A%B8-%EB%82%A0%EC%94%A8-2025-12-01/", "title": "서울 날씨 2025-12-01 | Rton\'s Notes", "content": "Skip to content\\n\\n2025년 12월 04일\\n\\nRton’s Notes\\n\\n Home\\n 날씨\\n 서울 날씨 2025-12-01\\n\\n 날씨\\n\\n# 서울 날씨 2025-12-01\\n\\nlorel3572    2025년 12월 01일\\n\\n서울 날씨 2025-12-01에 대한 핵심 내용을 한 문단으로 정리합니다. 본 정리는 서울 날씨 2025-12-01의 맥락과 체크포인트를 함께 담았습니다.\\n\\n### 2025년 12월 1일 서울 날씨 브리핑 — 서울 날씨 2025-12-01\\n\\n오늘 서울의 날씨는 대체로 맑고 온화한 편입니다. 아침부터 저녁까지 강수 확률은 0%로, 비나 눈이 내릴 가능성은 전혀 없습니다. 기온은 최저 0.9도에서 최고 10.9도까지 오르며, 체감 온도는 바람의 영향으로 다소 낮게 느껴질 수 있습니다.\\n\\n### 시간대별 날씨 요약", "score": 0.47387698, "raw_content": null}, {"url": "https://www.topstarnews.net/news/articleView.html?idxno=15630100", "title": "기상청, 내일 날씨 예보…서울 포함 전국 대부분 지역 비 (주말 날씨) - 김효진 기자 - 톱스타뉴스 - 사회", "content": "2025-12-23 22:17 (화). 기상청, 내일 날씨 예보…서울 포함 전국 대부분 지역 비 (주말 날씨). # 기상청, 내일 날씨 예보…서울 포함 전국 대부분 지역 비 (주말 날씨).  입력 2025.04.04 22:20. (톱스타뉴스 김효진 기자) 기상청에서 내일 날씨를 예보했다. 4일 오후 5시 기상청 발표에 따르면 내일 전국에 비가 내리고, 서해안과 제주도 산지를 중심으로 매우 강한 바람이 분다. 내일(5일)은 전국이 대체로 흐리고, 오전 12~6시부터 수도권과 강원중북부내륙, 산지, 충남북부서해안에 비가 시작된다. 예상 강수량은 서울, 인천, 경기, 서해5도 5~20mm, 강원내륙, 산지 5~20mm, 강원동해안 5mm 내외, 대전, 세종, 충남, 충북 5~20mm, 전북 5~10mm, 광주, 전남 5mm 내외, 경북북동내륙, 산지 5~10mm, 대구, 경북, 부산, 울산, 경남, 울릉도, 독도, 제주도 5mm 내외다. 예상 적설량은 강원중북부 높은 산지(해발고도", "score": 0.4362623, "raw_content": null}, {"url": "https://sml1.kosmos2022.com/entry/실시간-서울-날씨-완벽-가이드-오늘-내일-주간-월간-예보-총정리-2025년-최신", "title": "실시간 서울 날씨 완벽 가이드: 오늘, 내일, 주간, 월간 예보 총정리 (2025년 최신)", "content": "시간 절약: 여러 사이트를 돌아다니며 날씨 정보를 찾을 필요 없이, 이 글 하나로 모든 정보가 해결됩니다.\\n 정확도: 대한민국 기상청 날씨누리를 기반으로 가장 신뢰할 수 있는 날씨 정보를 제공합니다.\\n 최신 정보: 실시간 업데이트를 통해 항상 최신의 날씨 정보를 확인할 수 있습니다.\\n 맞춤 정보: 서울시 각 구별 날씨 정보는 물론, 여행, 문화 행사, 교통 정보까지 제공하여 서울 생활에 필요한 모든 정보를 얻을 수 있습니다.\\n\\n지금 바로 확인하세요! 🔍\\n\\n### 1. 대한민국 기상청 날씨누리 기반, 실시간 서울 날씨 예보 완벽 정리\\n\\n서울 날씨, 이제 흩어진 정보를 찾아 헤매지 마세요! 대한민국 기상청 날씨누리를 토대로, 실시간 업데이트되는 서울 날씨 정보를 쉽고 빠르게 확인할 수 있도록 완벽하게 정리했습니다.\\n\\n#### 1.1. 원하는 날씨 정보를 즉시 찾으세요!", "score": 0.40471974, "raw_content": null}], "response_time": 0.43, "request_id": "cf8c30ab-08a8-4173-941a-5189367d85de"}', name='tavily_search', tool_call_id='call_m7DoiLf6KX4w77InByk0Z9ZG')

# %%
search_result.content
# Out:
# '{"query": "서울 날씨 2025-12-30 기상청", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.kmib.co.kr/article/view_amp.asp?arcid=0029179968", "title": "오늘의 날씨 - 오전 (2025년 12월 30일)", "content": "오늘의 날씨 - 오전 (2025년 12월 30일) - 국민일보\\n\\nImage 1: 국민일보\\n\\n\\n\\n 입력 2025-12-30 05:31\\n\\nImage 3\\n\\n12월 30일 화요일, 아침 날씨입니다.\\n\\n아침 최저기온은 서울 -3.0도, 인천 -4.0도, 수원 -4.0도, 춘천 -5.0도, 강릉 -2.0도, 청주 -4.0도, 대전 -5.0도, 전주 -3.0도, 광주 -1.0도, 대구 -1.0도, 부산 2.0도, 제주 6.0도로 예상됩니다.\\n\\n낮 최고기온은 서울 2.0도, 인천 2.0도, 수원 2.0도, 춘천 3.0도, 강릉 4.0도, 청주 3.0도, 대전 4.0도, 전주 5.0도, 광주 6.0도, 대구 6.0도, 부산 8.0도, 제주 8.0도로 예상됩니다.\\n\\n이상 날씨였습니다.\\n\\n웨더봇 기자\\n\\n※ 이 기사는 국민일보가 개발한 기상뉴스 전용 인공지능 로봇 ‘웨더봇’이 기상청 데이터를 토대로 작성한 것입니다. 지속적인 업그레이드를 통해 더욱 풍부한 내용과 정확한 문장을 담아 가겠습니다.", "score": 0.8893851, "raw_content": null}, {"url": "https://kosmos13.tistory.com/entry/서울-날씨-완전-정복-실시간-예보-확인부터-기온별-옷차림-미세먼지-대처법까지", "title": "서울 날씨 완전 정복: 실시간 예보 확인부터 기온별 옷차림, 미세먼지 대처법까지", "content": "본문 바로가기\\n\\n# 하하호호1\\n\\n카테고리 없음\\n\\n# 서울 날씨 완전 정복: 실시간 예보 확인부터 기온별 옷차림, 미세먼지 대처법까지\\n\\n by 코스모스 13 2025. 12. 22.\\n\\n반응형\\n\\n서울 날씨, 변덕스럽기로 유명하죠? 강남에는 비가 오는데 강북은 맑은 이유부터 기상청 레이더 활용법, 봄·여름·가을·겨울 계절별 여행 팁과 옷차림 가이드, 그리고 미세먼지 최악인 날의 생존 전략까지. 서울의 사계절을 스마트하게 즐기는 모든 노하우를 담았습니다.\\n\\n단순히 \\"오늘 서울 비 오나요?\\"를 넘어, 구별 날씨 차이(열섬 현상), 미세먼지 대처법, 기온별 옷차림 공식, 장마철과 한파 생존 전략, 그리고 서울 여행하기 가장 좋은 시기까지 서울의 하늘 아래서 살아가는 데 필요한 모든 정보를 집대성했습니다.\\n\\n― \\"천만 시민의 하루를 결정하는 하늘\\" 서울의 4계절을 읽는 법", "score": 0.59655124, "raw_content": null}, {"url": "https://rtonblog.com/%EC%84%9C%EC%9A%B8-%EB%82%A0%EC%94%A8-2025-12-01/", "title": "서울 날씨 2025-12-01 | Rton\'s Notes", "content": "Skip to content\\n\\n2025년 12월 04일\\n\\nRton’s Notes\\n\\n Home\\n 날씨\\n 서울 날씨 2025-12-01\\n\\n 날씨\\n\\n# 서울 날씨 2025-12-01\\n\\nlorel3572    2025년 12월 01일\\n\\n서울 날씨 2025-12-01에 대한 핵심 내용을 한 문단으로 정리합니다. 본 정리는 서울 날씨 2025-12-01의 맥락과 체크포인트를 함께 담았습니다.\\n\\n### 2025년 12월 1일 서울 날씨 브리핑 — 서울 날씨 2025-12-01\\n\\n오늘 서울의 날씨는 대체로 맑고 온화한 편입니다. 아침부터 저녁까지 강수 확률은 0%로, 비나 눈이 내릴 가능성은 전혀 없습니다. 기온은 최저 0.9도에서 최고 10.9도까지 오르며, 체감 온도는 바람의 영향으로 다소 낮게 느껴질 수 있습니다.\\n\\n### 시간대별 날씨 요약", "score": 0.47387698, "raw_content": null}, {"url": "https://www.topstarnews.net/news/articleView.html?idxno=15630100", "title": "기상청, 내일 날씨 예보…서울 포함 전국 대부분 지역 비 (주말 날씨) - 김효진 기자 - 톱스타뉴스 - 사회", "content": "2025-12-23 22:17 (화). 기상청, 내일 날씨 예보…서울 포함 전국 대부분 지역 비 (주말 날씨). # 기상청, 내일 날씨 예보…서울 포함 전국 대부분 지역 비 (주말 날씨).  입력 2025.04.04 22:20. (톱스타뉴스 김효진 기자) 기상청에서 내일 날씨를 예보했다. 4일 오후 5시 기상청 발표에 따르면 내일 전국에 비가 내리고, 서해안과 제주도 산지를 중심으로 매우 강한 바람이 분다. 내일(5일)은 전국이 대체로 흐리고, 오전 12~6시부터 수도권과 강원중북부내륙, 산지, 충남북부서해안에 비가 시작된다. 예상 강수량은 서울, 인천, 경기, 서해5도 5~20mm, 강원내륙, 산지 5~20mm, 강원동해안 5mm 내외, 대전, 세종, 충남, 충북 5~20mm, 전북 5~10mm, 광주, 전남 5mm 내외, 경북북동내륙, 산지 5~10mm, 대구, 경북, 부산, 울산, 경남, 울릉도, 독도, 제주도 5mm 내외다. 예상 적설량은 강원중북부 높은 산지(해발고도", "score": 0.4362623, "raw_content": null}, {"url": "https://sml1.kosmos2022.com/entry/실시간-서울-날씨-완벽-가이드-오늘-내일-주간-월간-예보-총정리-2025년-최신", "title": "실시간 서울 날씨 완벽 가이드: 오늘, 내일, 주간, 월간 예보 총정리 (2025년 최신)", "content": "시간 절약: 여러 사이트를 돌아다니며 날씨 정보를 찾을 필요 없이, 이 글 하나로 모든 정보가 해결됩니다.\\n 정확도: 대한민국 기상청 날씨누리를 기반으로 가장 신뢰할 수 있는 날씨 정보를 제공합니다.\\n 최신 정보: 실시간 업데이트를 통해 항상 최신의 날씨 정보를 확인할 수 있습니다.\\n 맞춤 정보: 서울시 각 구별 날씨 정보는 물론, 여행, 문화 행사, 교통 정보까지 제공하여 서울 생활에 필요한 모든 정보를 얻을 수 있습니다.\\n\\n지금 바로 확인하세요! 🔍\\n\\n### 1. 대한민국 기상청 날씨누리 기반, 실시간 서울 날씨 예보 완벽 정리\\n\\n서울 날씨, 이제 흩어진 정보를 찾아 헤매지 마세요! 대한민국 기상청 날씨누리를 토대로, 실시간 업데이트되는 서울 날씨 정보를 쉽고 빠르게 확인할 수 있도록 완벽하게 정리했습니다.\\n\\n#### 1.1. 원하는 날씨 정보를 즉시 찾으세요!", "score": 0.40471974, "raw_content": null}], "response_time": 0.43, "request_id": "cf8c30ab-08a8-4173-941a-5189367d85de"}'

# %% [markdown]
# ##### tool_call 이 여러개일 경우
# - 질의에 대해 tool을 여러번 호출 해야 하는 경우 tool_calling 정보를 여러개 반환할 수 있다.
#     - 예) 검색할 키워드가 여러개인 경우.
# - `tool.batch([tool_call1, tool_call2, ..])`

# %%
query = "2025년 KBO, MLB, NPB 리그의 우승팀을 알려줘."
result = tool_model.invoke(query)

# %%
print(result.content)

# %%
result.tool_calls
# Out:
# [{'name': 'tavily_search',
#   'args': {'query': '2025 KBO 우승팀',
#    'search_depth': 'basic',
#    'include_images': False,
#    'topic': 'general'},
#   'id': 'call_lNqwwxoM7F1y8vi6yiNDFepQ',
#   'type': 'tool_call'},
#  {'name': 'tavily_search',
#   'args': {'query': '2025 World Series champion MLB 2025 champion',
#    'search_depth': 'basic',
#    'include_images': False,
#    'topic': 'general'},
#   'id': 'call_yysl1LMrnVZQ4BsuLkWKSBSR',
#   'type': 'tool_call'},
#  {'name': 'tavily_search',
#   'args': {'query': '2025 NPB 우승팀 Japan Series 2025 champion',
#    'search_depth': 'basic',
#    'include_images': False,
#    'topic': 'general'},
#   'id': 'call_aWcSKKFp2PGWyNVjZOFmUzFz',
#   'type': 'tool_call'}]

# %%
#LLM이 여러개의 툴을 가지고 있을 경우, 반복문 실행

# for tool_call in result.tool_calls:
#     tool_call.name => 호출할 툴 이름조회.
#     tool.invoke(tool_call)



# Runnable: invoke()/stream() - 개별 요청, batch(): 한번에 여러개 요청.

search_result_list = tavily_search.batch(result.tool_calls) # [toolcall, toolcall, ...]

# %%
search_result_list # list[ToolMessage]
# Out:
# [ToolMessage(content='{"query": "2025 KBO 우승팀", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://ko.wikipedia.org/wiki/2025%EB%85%84_%ED%95%9C%EA%B5%AD%EC%8B%9C%EB%A6%AC%EC%A6%88", "title": "2025년 한국시리즈 - 위키백과, 우리 모두의 백과사전", "content": "2025 신한 SOL Bank KBO 한국시리즈는 2025년 10월 26일부터 10월 31일까지 펼쳐진 2025년 KBO 리그의 챔피언 결정전이다. 대진은 2025년 KBO 리그 정규 시즌 1위 팀으로 2023년 한국시리즈 이후 2년만에 한국시리즈 직행에 성공하며 이번 시즌 통합 우승이자 통산 4번째 우승에 도전하는 LG 트윈스와 정규시즌 2위이자 플레이오프 승리팀으로 2006년 한국시리즈 이후 19년만에 한국시리즈에 진출해 통산 2번째 우승에 도전하는 한화 이글스가 맞붙었다. 두 팀의 한국시리즈 맞대결은 이번 포스트시즌 역사상 첫 맞대결이었다.\\n\\n결과는 LG 트윈스가 시리즈 전적 4승 1패로 2023년 한국시리즈 이후 2년 만의 통합 우승을 이뤄내면서 팀 통산 4번째 우승을 기록했다. 한국시리즈 MVP는 시리즈 기간 17타수 9안타 8타점을 기록, 기자단 투표 89표 중 61를 득표한 LG 트윈스의 외야수 김현수 \\"김현수 (1988년생 야구 선수)\\")가 차지했다. [...] ## KBO 포스트시즌 대진표\\n\\n[편집]\\n\\n이 부분의 본문은 2025년 KBO 포스트시즌입니다.\\n\\n|  |  |  |  |  |  |  |  |  |  |  |\\n ---  ---  ---  ---  --- \\n|  | 와일드카드 결정전 |  |  | 준플레이오프 |  |  | 플레이오프 |  |  | 한국시리즈 |\\n|  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |\\n|  |  | 1 | LG 트윈스 | 4 |\\n|  |  | 2 | 한화 이글스 | 3 |  |  | 2 | 한화 이글스 | 1 |\\n|  |  | 3 | SSG 랜더스 | 1 |  |  | 4 | 삼성 라이온즈 | 2 |  |\\n|  | 4 | 삼성 라이온즈 | 1 |  |  | 4 | 삼성 라이온즈 | 3 |  |\\n|  | 5 | NC 다이노스 | 1 |  |\\n\\n### 와일드카드 결정전\\n\\n[편집] [...] | 2025년 한국시리즈 |\\n| |  |  |  --- | |  |  | |\\n| |  |  |  --- | | 팀 | 승(무승부) | | LG 트윈스 | 4 | | 한화 이글스 | 1 | |\\n| 경기 정보 |\\n| 경기 일정 | 2025년 10월 26일 ~ 10월 31일 |\\n| MVP | 김현수 \\"김현수 (1988년생 야구 선수)\\") |\\n| 팀 정보 |\\n| LG 트윈스 |\\n| 감독 | 염경엽 |\\n| 시즌 성적 | 85승 3무 56패 (정규시즌 1위) |\\n| 한화 이글스 |\\n| 감독 | 김경문 |\\n| 시즌 성적 | 83승 4무 57패 (정규시즌 2위) |\\n| |  |  |  --- | | < 2024 |  | |", "score": 0.8793233, "raw_content": null}, {"url": "https://ko.wikipedia.org/wiki/2025%EB%85%84_KBO_%EB%A6%AC%EA%B7%B8", "title": "2025년 KBO 리그 - 위키백과, 우리 모두의 백과사전", "content": "여기를 가리키는 문서\\n 가리키는 글의 최근 바뀜\\n 파일 올리기\\n 고유 링크\\n 문서 정보\\n 이 문서 인용하기\\n 축약된 URL 얻기\\n QR코드 다운로드\\n\\n인쇄/내보내기\\n\\n 책 만들기\\n PDF
of \\"Japan\'s Number One.\\" Games are played in a maximum of 7 contests, typically held from late October to early November. The \\"Korea Series\\" in Korean professional baseball (KBO) is the final championship battle that determines the season champion, equivalent to Japan\'s \\"Japan Series\\" or America\'s \\"World Series.\\" **This series, which concludes the KBO League\'s postseason, features a clash between the first-place team from the regular season and the team that advanced through the playoffs.** Played in a best-of-seven format, the winning team claims the crown as that year\'s \\"KBO Champion.\\".", "score": 0.999617, "raw_content": null}, {"url": "https://dev.firsteconomy.com/kanakia-paris/?s-news-3407560-2025-10-30-", "title": "SoftBank Hawks Clinch 2025 Nippon Series Title After Dominant ...", "content": "The 2025 Nippon Professional Baseball (NPB) season concluded with the SoftBank Hawks claiming the coveted Nippon Series title.", "score": 0.99869555, "raw_content": null}, {"url": "ht ...

# %% [markdown]
# ### 3. Tool의 처리(응답) 결과를 LLM 요청시 사용
# - ToolMessage를 prompt 에 추가하여 LLM에 요청한다.
# - ToolMessage 는 Tool Calling 정보를 가진 AIMessage 다음에 들어와야 한다.
# - Prompt 순서
#     1. 일반 prompt (system, 대화 history, .., human)
#     2. AIMessage: tool calling 정보를 가진 AIMessage. (tool_model에 질의 받은 tool calling 정보가 있는 응답)
#     3. ToolMessage:  Tool의 처리 결과

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

prompt = ChatPromptTemplate(
    [
        ("system", "당신은 AI Assistant 입니다. 제공된 정보를 바탕으로 답변해 주세요."),
        ("human", "{query}"),
        MessagesPlaceholder(variable_name="tool_messages", optional=True)
    ]
)

chain = prompt | tool_model
final_result = chain.invoke(
    {
        "query":query,
        "tool_messages":[result, *search_result_list]
    }
)

# 어떤 툴들을 호출해서 어떤 결과를 얻었는지를 전달.
# "tool_messages":[result:toolcall 정보가 있는 AI Massage, *search_result_list : ToolMessage-tool의 처리결과]

# %%
print(final_result.content)
# Out:
# 다음과 같습니다.
#
# - KBO: LG 트윈스 — 2025 한국시리즈 우승 (LG 트윈스 4–1 한화 이글스)
# - MLB: Los Angeles Dodgers — 2025 월드 시리즈 우승 (다저스 4–3 Toronto Blue Jays)
# - NPB: Fukuoka SoftBank Hawks (후쿠오카 소프트뱅크 호크스) — 2025 일본시리즈 우승 (SoftBank 4–1 Hanshin Tigers)
#
# 원하시면 각 시리즈의 주요 경기·MVP·우승 확정일 등 상세 정보도 드릴게요.

# %%
final_result.tool_calls
# Out:
# []

# %%
#Agent chain 을 구성

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables import chain
from langchain_tavily import TavilySearch
from dotenv import load_dotenv
from datetime import date

load_dotenv()
# Out:
# True

# %%
tavily_search = TavilySearch()
model = ChatOpenAI(model="gpt-5-mini")

tool_model = model.bind_tools(tools=[tavily_search]) #모델에 툴을 바인딩

system_message = """#instruction
당신은 다양한 질문에 답을 하는 AI assistant 입니다.
사용자 질문에 대해 최신 정보를 바탕으로 답변해주세요.
오늘 날짜는 {today} 입니다.
필요하다면 tool을 이용해 답변에 필요한 정보를 수집합니다.
당신이 사용할 수 있는 Tool은 다음과 같습니다.
-tavily_search: 웹 검색 툴
"""
today = date.today().strftime("%Y년 %m월 %d일") # %H시간, %M:분, %S:초
prompt = ChatPromptTemplate(
    [
        ("system", system_message),
        ("human","{query}"),
        MessagesPlaceholder(variable_name="tool_messages", optional=True)
    ],
    prtial_variables={"today":today}
)

tool_model_chain = prompt | tool_model

# %%
prompt| tool_model| tool호출/응답

# %%
tool_model_chain.invoke({"query": "날씨를 알려줘"})
# Out:
# AIMessage(content='어느 지역 날씨를 알려드릴까요? (예: 서울, 부산, 제주)  \n그리고 현재 날씨인지/오늘·내일인지/주간 예보인지, 특정 시간(예: 내일 오전 9시) 중 무엇을 원하시는지도 알려주세요.  \n온도 단위는 섭씨(°C)로 드려도 될까요? 바로 조회해 드릴게요.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 354, 'prompt_tokens': 1354, 'total_tokens': 1708, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CsfHs43hMDxBRfAAob5FAH4pgjSil', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b7204-7c13-7ce0-a265-a40dfddf98a6-0', usage_metadata={'input_tokens': 1354, 'output_tokens': 354, 'total_tokens': 1708, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}})

# %%
@chain
def websearch_agent(query:str) -> tuple[str, list]:
    """ 
    Agent 전체 흐름을 처리하는 Runnabel
    사용자 질문 (query)를 받아서 tool_model 과 tool을 이용해서 최종 응답을 반환한다.
    ReAct 구조로 구성. (ReAct Loop)
    """
    ai_message = tool_model_chain.invoke({"query":query}) # 반환: 1. 실제 응답, 2.tool calls 정보
    messages = [] # toolcall메세지, ToolMessage 들 저장 리스트(prompt tool_messages에 넣을 것)
    while ai_message.tool_calls: # 빈 리스트가 아니라면.
        #Tool 호출
        tool_messages = tavily_search.batch(ai_message.tool_calls) #[TM, TM, ...]
        messages.extend([ai_message, *tool_messages])
        #tool 호출 결과를 넣어서 tool_model 에 다시 요청
        ai_message = tool_model_chain.invoke({"query":query, "tool_messages":messages})
    
    messages.append(ai_message) #마지막 응답 결과를 추가.
    return ai_message.content, messages #AIMessage

# agent 로직 -> LangGraph

# %%
result = websearch_agent.invoke("안녕하세요")

# %%
result
# Out:
# ('안녕하세요! 만나서 반갑습니다. 무엇을 도와드릴까요? (질문, 번역, 일정관리, 추천 등 어떤 도움이 필요하신지 알려주세요.)',
#  [AIMessage(content='안녕하세요! 만나서 반갑습니다. 무엇을 도와드릴까요? (질문, 번역, 일정관리, 추천 등 어떤 도움이 필요하신지 알려주세요.)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 111, 'prompt_tokens': 1351, 'total_tokens': 1462, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CsfTD6Tx0uB9I4U0turL7f11M1CWH', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b720f-355b-7c81-9280-e1a28db7b504-0', usage_metadata={'input_tokens': 1351, 'output_tokens': 111, 'total_tokens': 1462, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}})])

# %%
result2= websearch_agent.invoke("서울 날씨가 어떤지 알려줘")

# %%
print(result2[0])
# Out:
# 원하시는 정보가 무엇인가요?
# - 지금(현재) 기온·하늘 상태 알려드릴까요, 아니면 오늘 하루(시간대별) 예보를 원하시나요?
# - 미세먼지(PM2.5·PM10) 정보도 함께 볼까요?
#
# 원하시는 항목 말씀해주시면 바로 최신 정보로 조회해 알려드릴게요.

# %%
result2[1]
# Out:
# [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 106, 'prompt_tokens': 1357, 'total_tokens': 1463, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CsfUUEpIoLaseXqWOvipWGnpUlloD', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b7210-68c7-7960-901d-9931ec3bd111-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': '서울 현재 날씨', 'search_depth': 'fast', 'topic': 'general', 'time_range': 'day'}, 'id': 'call_vcMLf5nXsIvLc8hC16dTXY19', 'type': 'tool_call'}], usage_metadata={'input_tokens': 
랄블로킹 발달 등의 영향으로, 봄이 온다는 입춘(3일부터 10일까지)과 얼음이 녹는다는 우수(18일부터 24일까지)에 추위가 각각 일주일 이상 지속되었다. \\\\ 북대서양(그린란드 남쪽 해양)에서 [...] 최근 10년 평균보다 0.2℃ 높았으며, 최근 10년 중 두 번째로 높았다(1위: 2019년 12.8℃).", "score": 0.5786631, "raw_content": null}, {"url": "https://www.kma.go.kr/eng/biz/climate_01.jsp", "title": "기상청", "content": "(042)481-7500. 서울 (07062) 서울특별시 동작구 여의대방로16길 61 / 전화 (02)2181-0900. 전자우편(웹사이트 관련 문의): webmasterkma@korea.kr. All Rights RESERVED 전자우편(웹사이트 관련 문의): webmasterkma@korea.kr.", "score": 0.52773094, "raw_content": null}, {"url": "https://www.kma.go.kr/weather/special/special_03_final.jsp?sido=4100000000&gugun=4159000000&dong=4159055000", "title": "기상청", "content": "# 이 누리집은 대한민국 공식 전자정부 누리집입니다. # \\"하늘을 친구처럼, 국민을 하늘처럼\\". # 기상청. “서비스 이용에 불편을 드려 죄송합니다.”. 서비스 장애가 계속될 경우, 아래로 문의 바랍니다. 전화: (02)2181-0900, (042)481-7500. 기상 관련 문의: 기상콜센터(131). ※ 날씨누리에 접속 시 해당화면이 나타났다면 다음을 확인해주세요. - 기상청 날씨누리는 『 』 시작되는 페이지만 운영합니다.(21년 이후). - 그 외 접속 페이지는 현재 서비스 및 관리를 하지 않는 페이지 임을 알려드립니다. 대전 (35208) 대전광역시 서구 청사로 189 정부대전청사 1동 11~14층 / 전화 (042)481-7500. 서울 (07062) 서울특별시 동작구 여의대방로16길 61 / 전화 (02)2181-0900. 전자우편(웹사이트 관련 문의): webmasterkma@korea.kr. 전자우편(웹사이트 관련 문의): webmasterkma@korea.kr.", "score": 0.46424627, "raw_content": null}, {"url": "https://www.kma.go.kr/daegu", "title": "기상청", "content": "# 이 누리집은 대한민국 공식 전자정부 누리집입니다. # \\"하늘을 친구처럼, 국민을 하늘처럼\\". # 기상청. “서비스 이용에 불편을 드려 죄송합니다.”. 서비스 장애가 계속될 경우, 아래로 문의 바랍니다. 전화: (02)2181-0900, (042)481-7500. 기상 관련 문의: 기상콜센터(131). ※ 날씨누리에 접속 시 해당화면이 나타났다면 다음을 확인해주세요. - 기상청 날씨누리는 『 』 시작되는 페이지만 운영합니다.(21년 이후). - 그 외 접속 페이지는 현재 서비스 및 관리를 하지 않는 페이지 임을 알려드립니다. 대전 (35208) 대전광역시 서구 청사로 189 정부대전청사 1동 11~14층 / 전화 (042)481-7500. 서울 (07062) 서울특별시 동작구 여의대방로16길 61 / 전화 (02)2181-0900. 전자우편(웹사이트 관련 문의): webmasterkma@korea.kr. 전자우편(웹사이트 관련 문의): webmasterkma@korea.kr.", "score": 0.46424627, "raw_content": null}], "response_time": 0.5, "request_id": "25a6557b-67a1-4af4-bc23-e63df579e6a2"}', name='tavily_search', tool_call_id='call_VjTt5TzaCYaywndmksqqoxws'),
#  AIMessage(content='원하시는 정보가 무엇인가요?\n- 지금(현재) 기온·하늘 상태 알려드릴까요, 아니면 오늘 하루(시간대별) 예보를 원하시나요?\n- 미세먼지(PM2.5·PM10) 정보도 함께 볼까요?\n\n원하시는 항목 말씀해주시면 바로 최신 정보로 조회해 알려드릴게요.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 347, 'prompt_tokens': 6245, 'total_tokens': 6592, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CsfUdtqPUnC4RC9wCR8estMIxlPcY', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b7210-8f37-7373-a53f-816bccbfc885-0', usage_metadata={'input_tokens': 6245, 'output_tokens': 347, 'total_tokens': 6592, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}})]

# %%
result2= websearch_agent.invoke("서울 날씨가 어떤지 알려줘")

# %% [markdown]
# # 사용자 정의 Tool 구현
#
# ## @tool 사용
# - 함수로 구현하고 `@tool` 데코레이터를 사용해 tool(StructuredTool)로 정의한다.
#     - `langchain_core.tools` 모듈에 있다.
# - tool name
#     - 함수의 이름이 tool의 이름이 된다.
# - parameters
#     - 함수의 파라미터가 tool의 파라미터가 된다.
#     - **type hint**를 이용해 타입을 지정한다.
# - description
#     - doctring이 description이 된다.
#     - RunnableBinding이 tool을 잘 찾을 수 있도록 하려면 **tool의 기능을 최대한 구체적**으로 작성한다.
# - **@tool이 적용된 함수(StructuredTool)이 tool**이므로 model에 binding 한다.

# %%
from langchain_core.tools import tool

@tool
def plus(num1:int|float, num2:int|float) -> int|float:
    """두개 수를 받아서 덧셈한 결과를 반환하는 툴"""
    return num1 + num2


@tool
def minus(num1:int|float, num2:int|float) -> int|float:
    """두개 수를 받아서 뺄셈한 결과를 반환하는 툴"""
    return num1 - num2

@tool
def multiply(num1:int|float, num2:int|float) -> int|float:
    """두개 수를 받아서 곱셈한 결과를 반환하는 툴"""
    return num1 * num2

#파라미터에 대한 자세한 설명이 들어가야 하는 경우 - > Pydantic
from pydantic import BaseModel, Field
class DivideParameterSchema(BaseModel):
    num1: int|float=Field(..., description="나눌 때 사용할 첫번째 값")
    num2: int|float=Field(..., description="나눌 때 사용할 두번째 값")

@tool("divide_tool", args_schema=DivideParameterSchema)
def divide(num1:int|float, num2:int|float) -> int|float:
    """두개 수를 받아서 나눈 결과를 반환하는 툴"""
    return num1 / num2

# %%
print(type(divide))
print("툴이름:",divide.name)
print("툴설명:",divide.description)
print("args schema(파라미터설명)")
divide.args_schema.model_json_schema()
# Out:
# <class 'langchain_core.tools.structured.StructuredTool'>
# 툴이름: divide_tool
# 툴설명: 두개 수를 받아서 나눈 결과를 반환하는 툴
# args schema(파라미터설명)
# {'properties': {'num1': {'anyOf': [{'type': 'integer'}, {'type': 'number'}],
#    'description': '나눌 때 사용할 첫번째 값',
#    'title': 'Num1'},
#   'num2': {'anyOf': [{'type': 'integer'}, {'type': 'number'}],
#    'description': '나눌 때 사용할 두번째 값',
#    'title': 'Num2'}},
#  'required': ['num1', 'num2'],
#  'title': 'DivideParameterSchema',
#  'type': 'object'}

# %%
calc_model = ChatOpenAI(model="gpt-5-mini").bind_tools(tools=[plus, minus, multiply, divide])
calc_model.invoke("3+5-20 은 얼마야? 계산에 사용할 툴이 있으면 툴을 사용해 줘")
# Out:
# AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 284, 'prompt_tokens': 316, 'total_tokens': 600, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CsgCd2Vi5Mi0s4XNSwY7ASEsZLwWT', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b723a-2ac9-78d2-b545-8847e4e2333f-0', tool_calls=[{'name': 'plus', 'args': {'num1': 3, 'num2': 5}, 'id': 'call_rJA6hZdY0AflNQsM8l7P9hR3', 'type': 'tool_call'}], usage_metadata={'input_tokens': 316, 'output_tokens': 284, 'total_tokens': 600, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}})

# %% [markdown]
# ## Runnable을 tool로 정의
# - `Runnable객체.as_tool()`
#     - name, description, args_schema 파라미터를 이용해 tool의 이름, 설명, 스키마를 설정한다.

# %%
from langchain_community.document_loaders import WikipediaLoader # 위키백과 사전 내용을 크롤링 해서 문서로 반환
from pydantic import BaseModel, Field
from langchain_core.runnables import chain
import json

@chain
def wikipedia_search(inputs: dict) -> str:
    """ 사용자 query를 위키백과사전에서 검색하고 검색 결과중 k개 문서를 반환한다.
    Args:
        inputs(dict): `query-검색할 키워드, max_results(int): 반환할 검색 결과 수`를 받는다.
    Returns:
        str - 검색결과를 json 으로 반환. 형식: {"result":[{검색 문서1}, {검색 문서2}, ...]}. 검색 문서(dict) - content, url, title 로 구성.
        검색결과가 없을 경우 : {"result":"결과없음"} 반환.
    """

    query = inputs["query"]
    max_results = inputs.get("max_results", 5)
    loader = WikipediaLoader(query=query, load_max_docs=max_results, lang="ko")
    docs = loader.load()

    result_list = []
    for doc in docs:
        result_list.append({"content":doc.page_content, "title":doc.metadata.get('title'), "url":doc.metadata.get("source")})

    if result_list:
        result = {"result": result_list}
    else:
        result = {"result": "검색결과가 없습니다."}

    #JSON 문자열로 변환해서 반환 #json.load() : json문자열 -> 파이썬 자료구조, json.dumps() :파이썬 자료구조 -> json
    return json.dumps(result, ensure_ascii=False) # ensure_ascii=False: 한글문자가 나오도록 처리. True : 한글이 유니코드  escape 문자로 나옴

# %%
# !uv pip install wikipedia
# Out:
# Resolved 9 packages in 5.30s
#    Building wikipedia==1.4.0
#       Built wikipedia==1.4.0
# Prepared 1 package in 1.06s
# Installed 1 package in 31ms
#  + wikipedia==1.4.0

# %%
r=wikipedia_search.invoke({"query":"월드컵", "max_results":3})
json.loads(r) #문자열을 json형식으로 보여줌
# Out:
# {'result': [{'content': 'FIFA 월드컵(영어: FIFA World Cup)은 축구 국제 기구인 국제 축구 연맹(FIFA)에 가맹한 축구 협회(연맹)의  축구 국가대표팀만 참가하는 국제 축구 대회이다.\n4년마다 열리는 월드컵은 1930년에 첫 대회가 열렸다. 1942년과 1946년 대회는 제2차 세계 대전으로 인하여 열리지 못했다. 대회는 예선 무대와 본선 무대 등 두 부분으로 나뉜다. 예선 무대는 본선에 진출할 32팀을 가려내기 위해 본선 보다 3년 일찍 시작한다. 현재 본선은 개최국 경기장에서 한 달 남짓 32개 팀이 우승을 놓고 경쟁하는 방식으로 진행된다. 월드컵 결승전은 세계에서 가장 많은 사람이 시청하는 단일 스포츠 경기이다. 어림잡아 7억 1,510만 명이 2006년 FIFA 월드컵 결승전을 시청했다고 한다.\n총 20번 대회가 열리는 동안 8팀이 우승을 차지했다. 가장 우승 횟수가 많은 팀은 브라질로 총 다섯 번의 우승컵을 들어올렸다. 그 다음으로 이탈리아와 독일이 네 번, 아르헨티나가 세 번, 그리고 초대 우승팀인 우루과이와 프랑스가 각각 두 차례씩, 잉글랜드와 스페인가 각각 한 차례씩 우승을 차지했다. 네덜란드는 준우승만 3번(1974·1978·2010)했다.대한민국은 4위가 최고 기록이다.(2002)\n가장 최근에 열린 2022년 FIFA 월드컵은 카타르에서 열�
IFA 월드컵의 마지막 두 자리를 결정하는 대륙간 플레이오프 토너먼트가 포함된다.\n\n다수의 개최국이 존재하는 상황에서 자동 개최국 자격을 부여하는 방식에 대한 문제는 아직 해결되지 않았으며 FIFA 평의회에서 결정할 예정이다.\n북미 3국 유치팀은 3개 개최국 모두가 자동으로 자리를 차지할 것으로 예상했다.\n슬롯 배정 비준으로 오세아니아는 FIFA 월드컵 역사상 처음으로 월드컵 본선 진출이 보장되었다. 2026년 FIFA 월드컵은 6개 연맹이 모두 참가권을 보장받은 최초의 토너먼트가 될 것이다.\n\n\n=== 대륙간 플레이오프 ===\n6개 팀이 참가하는 플레이오프가 개최되어, FIFA 월드컵의 마지막 두 자리를 결정한다. 연맹당 1팀(유럽 제외)과 연맹의 추가 1팀으로 구성 개최 대륙(북중미)된다. FIFA 세계 랭킹에 따라 두 팀들이 시드되 시드된 팀은 시드되지 않은 4개 팀이 참가하는 첫 두 경기의 승자와 FIFA 월드컵 접전을 펼친다. 토너먼트는 개최국에서 진행되며, FIFA 월드컵의 테스트 이벤트로 사용되며, 2025년 11월과 2026년 3월의 기존 플레이오프 기간이 2026년 판의 잠정 날짜로 제안되었다.\n\n\n== 본선 ==\n4팀씩 12개조로 나누어서 조별리그를 진행하며 각 조의 1위와 2위를 차지한 24팀과 각 조 3위팀 중 상위 8팀이 32강 토너먼트에 합류한다.\n\n\n== 개최 도시 및 경기장 ==\n입찰 과정에서 41개 도시에서 43개의 기존의 완전한 기능을 갖춘 경기장과 2개의 건설 중인 경기장이 입찰의 일부로 제출(멕시코 3개 도시에 3개 경기장, 캐나다 7개 도시에 9개 경기장, 미국 34개 도시에 38개 경기장)되었다.1라운드 탈락으로 9개의 장소와 9개의 도시가 중단: 2차 예선 탈락으로 6개 도시에서 9개 경기장이 추가로 줄어들었고, FIFA가 재정 세부 사항에 대해 논의하지 않으려는 이유로 3개 도시(시카고, 미니애폴리스, 밴쿠버)에서 3개 경기장이 탈락했다. 2021년 7월 몬트리올이 중단된 후 밴쿠버는 2022년 4월 후보 도시로 복원되어 각각 고유한 도시 또는 대도시 지역(로스앤젤레스 제외)에 총 24개의 장소가 생겼다. 워싱턴 D.C.와 볼티모어는 입찰을 결합하여 DC의 FedExField를 제거하고 볼티모어의 M&T 뱅크 스타디움과 페덱스필드의 열악한 상태에 대한 우려로 선택한 경기장으로 만들었으나, 이번 입찰을 위한 FIFA 팬 페스트 이벤트는 DC 내셔널 몰에서 개최된다.\n캐나다와 미국에는 스포츠를 염두에 두고 설계된 '축구 전용 경기장'이 있지만, 미국 최대 규모의 축구 전용 경기장인 지오디스 파크(Geodis Park)는 3만석으로 FIFA가 기준으로 정해놓은 최소 4만석에 못 미치는 수준이다. MLS 홈경기장으로 사용되는 곳은 이번 대회를 위해 30,000에서 45,500으로 확장되나, 애틀랜타의 메르세데데스-벤츠 스타디움과 시애틀의 루멘 필드와 같이 NFL과 MLS 팀이 모두 사용하는 경기장이 주로 골대 풋볼에 사용되었지만, 내셔널 풋볼 리그 팀 및 NCAA 디비전 I 대학 풋볼 프로그램을 주최한 미식 경기장과 캐나다 풋볼 리그(CFL)를 주최하는 캐나다 스타디움과 함께 모든 캐나다 및 미식 경기장이 사용되었다. 협회 축구 경기를 위한 수많은 기회와 협회 축구 이벤트를 주최하도록 설계되었다.\n2022년 6월 16일 FIFA에서 개최 도시를 발표했다. 서부 디비전의 밴쿠버, 시애틀, 샌프란시스코, 로스앤젤레스, 과달라하라, 센트럴 디비전의 캔자스시티, 댈러스, 휴스턴, 애틀랜타, 몬테레이, 멕시코시티, 토론토, 동부 디비전의 보스턴, 뉴욕시, 필라델피아 및 마이애미(캐나다 2개, 멕시코 3개, 미국 11개)이다.\n\n는 이전 남자 월드컵 토너먼트에 사용된 경기장을 나타냄(미국과 멕시코만 해당).\n은 고정식 또는 수납식 지붕이 있는 실내 경기장을 나타냄.\n\n\n=== 캐나다 ===\n\n\n=== 멕시코 ===\n\n\n=== 미국 ===\n\n\n=== 조 추첨 ===\n추첨은 2025년 12월 5일 금요일 낮 12:00 UTC−5(EST(북미 동부 표준시))에 워싱턴 D.C.의 케네디 센터에서 진행될 것이다. 48개 팀은 12개 팀씩 4개의 포트로 나뉠 것이다. 포트 1은 개최국 3개 팀과 2025년 11월 FIFA 남자 세계 랭킹 상위 9개 팀으로 구성될 것이다. 포트 2, 3, 4는 랭킹에 따라 나머지 팀으로 구성된다. 유럽 예선 플레이오프의 4개 우승자들와 대륙간 플레이오프의 2개 승자들는 추첨 당시에는 알 수 없다. 이러한 경기는 2026년 3월에 진행될 예정이어서 자동으로 포트 4에 할당되었다. 12개 조들은 4개의 포트에서 각각 한 팀씩 선택하여 무작위로 구성된다. 같은 대륙 간 플레이오프 우승팀을 포함한 UEFA 팀을 제외하고, 같은 조에 편성될 수 없다. UEFA 팀은 조당 최소 1팀에서 최대 2팀까지만 편성되어야  ...
#    'title': '2026년 FIFA 월드컵',
#    'url': 'https://ko.wikipedia.org/wiki/2026%EB%85%84_FIFA_%EC%9B%94%EB%93%9C%EC%BB%B5'}]}

# %%
r
# Out:
# '{"result": [{"content": "FIFA 월드컵(영어: FIFA World Cup)은 축구 국제 기구인 국제 축구 연맹(FIFA)에 가맹한 축구 협회(연맹)의  축구 국가대표팀만 참가하는 국제 축구 대회이다.\\n4년마다 열리는 월드컵은 1930년에 첫 대회가 열렸다. 1942년과 1946년 대회는 제2차 세계 대전으로 인하여 열리지 못했다. 대회는 예선 무대와 본선 무대 등 두 부분으로 나뉜다. 예선 무대는 본선에 진출할 32팀을 가려내기 위해 본선 보다 3년 일찍 시작한다. 현재 본선은 개최국 경기장에서 한 달 남짓 32개 팀이 우승을 놓고 경쟁하는 방식으로 진행된다. 월드컵 결승전은 세계에서 가장 많은 사람이 시청하는 단일 스포츠 경기이다. 어림잡아 7억 1,510만 명이 2006년 FIFA 월드컵 결승전을 시청했다고 한다.\\n총 20번 대회가 열리는 동안 8팀이 우승을 차지했다. 가장 우승 횟수가 많은 팀은 브라질로
 해씩 미뤄져 제4회 대회는 1950년, 제5회 대회는 1954년 개최되게 되었다.\\n\\n\\n=== 시련 이후 계속되는 성장 ===\\n\\n1950년 FIFA 월드컵은 처음으로 영국의 팀들이 참가한 대회였다. 영국의 일부 팀들은 그들과 전쟁했던 나라들과의 대결하기를 꺼렸고 또 그들의 팀들이 다른 나라의 축구에 영향을 주는 것을 항의하고자 1920년에 FIFA에서 탈퇴했으나, 그러나 FIFA의 초청에 따라 1946년에 다시 가입했다. 추가로 1950년 월드컵은 한국 전쟁이 발발한 시각과 동일한 시각에 개막되었다. 그리고 1950년 대회에서는 또한, 제1회 대회의 우승국이었던 우루과이가 이전 두 대회의 참가 거부 끝에 복귀했다. 우루과이는 이 대회에서 다시 한 번 우승했고 이 대회는 마라카낭의 비극이라고 하는 역사상 유명한 경기로 후에 남게 되었다. 우루과이에 패배한 브라질은 그 굴욕을 참지 못해 유니폼의 색깔이 변경되었다.\\n1934년부터 1978년 대회까지는 1938년 대회에서 오스트리아가 나치 독일에 예선 통과 후에 흡수됨에 따라 15개 팀의 참가로 치러진 경우와, 1950년 대회에서  ...

# %%
# Runnable을 tool로 변환 -> as_tool(툴설정)
## args_schema 설정
class WikiSearchParameterSchema(BaseModel):
    query: str = Field(..., description="Wikipedia에서 검색할 keyword")
    max_results: int = Field(description="검색할 결과 문서의 최대 개수. 생략하면 5개를 검색")

search_wiki = wikipedia_search.as_tool(
    args_schema=WikiSearchParameterSchema,
    name="search_wiki",
    description="""이 도구는 위키피디아에서 정보를 검색할 때 사용한다.
사용자의 질문과 관련된 내용을 위키피디아에서 검색해 지정한 개수의 문서만큼 반환한다.
일반적인 지식이나 백과사전 식 정보가 필요할 때 사용한다.
"""
)

# %%
print(search_wiki.name)
print(search_wiki.description)
search_wiki.args_schema.model_json_schema()
# Out:
# search_wiki
# 이 도구는 위키피디아에서 정보를 검색할 때 사용한다.
# 사용자의 질문과 관련된 내용을 위키피디아에서 검색해 지정한 개수의 문서만큼 반환한다.
# 일반적인 지식이나 백과사전 식 정보가 필요할 때 사용한다.
# {'properties': {'query': {'description': 'Wikipedia에서 검색할 keyword',
#    'title': 'Query',
#    'type': 'string'},
#   'max_results': {'description': '검색할 결과 문서의 최대 개수. 생략하면 5개를 검색',
#    'title': 'Max Results',
#    'type': 'integer'}},
#  'required': ['query', 'max_results'],
#  'title': 'WikiSearchParameterSchema',
#  'type': 'object'}

# %%
tool_model = ChatOpenAI(model="gpt-5-mini").bind_tools(tools=[search_wiki])

res = tool_model.invoke("월드컵에 대한 내용을 위키백과사전에서 조회해 정리해줘.")

# %%
print(res.content)
res.tool_calls
# Out:
# [{'name': 'search_wiki',
#   'args': {'query': '월드컵', 'max_results': 5},
#   'id': 'call_VGVJRRWlTcdJxt0134Dea4Tr',
#   'type': 'tool_call'}]

# %% [markdown]
# ## Vector Store(Vector 저장소) tool
#
# ### text loading -> Document 생성
# - 레스토랑 메뉴를 vector store에 저장한다.
# 1. 메뉴 text 를 로딩한다.
# 2. 각 메뉴의 내용(음식이름, 메뉴설명, 파일명)을 넣어 Document를 생성한다.

# %%
# 문서 Load
import os
# 메뉴읽어 오기
menu_file_path = "data/restaurant_menu.txt"
with open(menu_file_path, "r", encoding="utf-8") as f:
    menu = f.read()

# %%
# Split - 메뉴별로 분리하기 위해 직접 처리
from langchain_core.documents import Document
import re
from pprint import pprint

def create_documents(menu_all: str, file_name) -> list[Document]:
    """메뉴별로 분리 한뒤 Document로 변환. 변환된 Document들을 리스트로 반환
    metadata: 메뉴이름, 주요 재료, 가격, source(파일이름)
    """
    menu_list = menu_all.split("\n\n")
    menu_documents = [] # 개별 메뉴로 Document를 생성 그것들을 저장할 list
    for menu_item in menu_list:

        # 메뉴 이름 추출
        menu_name_pattern = r"(^\d+.\s)([가-힣a-zA-Z\d ]+)"
        menu_name_result = re.search(menu_name_pattern, menu_item)
        menu_name = menu_name_result.group(2).strip()  # 메뉴 이름 추출 # 1은 번호

        # 주요재료 추출 - text로 indexing.
        menu_ingredient_pattern = r"(?<=주요 재료: ).+" # 검색할때는 찾지만, 결론을 반환할 때는 제외.
        ingredients = re.search(menu_ingredient_pattern, menu_item).group().strip()
    
        # 가격추출
        price_pattern = r"(?<=가격: )[\d,]+(?=원)"
        price_result = re.search(price_pattern, menu_item)
        price = int(price_result.group().replace(",", ""))

        
        # 메뉴 이름을 제외한 나머지는 메뉴 설명으로 간주
        menu_doc = Document(
            page_content=menu_item,     # 메뉴 설명을 page_content에 넣는다. metadata는 나중에 따로 따로 payload filtering 할 수있기 때문에 
            metadata={
                "menu_name": menu_name, # 메뉴 이름
                "price": price,         # 가격
                "ingredients": ingredients, # 재료 리스트
                "source": file_name     # 메뉴가 저장된 파일 이름
            }
        )
        menu_documents.append(menu_doc)
    return menu_documents


menu_documents = create_documents(menu, menu_file_path)
print(len(menu_documents))
menu_documents[0]
# Out:
# 15
# Document(metadata={'menu_name': '라따뚜이', 'price': 17000, 'ingredients': '가지, 호박, 파프리카, 토마토 소스, 올리브 오일', 'source': 'data/restaurant_menu.txt'}, page_content='1. 라따뚜이\n   - 가격: 17,000원\n   - 주요 재료: 가지, 호박, 파프리카, 토마토 소스, 올리브 오일\n   - 메뉴 설명: 프랑스 남부를 대표하는 전통 요리로, 신선한 채소를 얇게 썰어 층층이 쌓아 올리고 허브와 토마토 소스를 더해 구워냅니다. 채소 본연의 단맛과 상큼한 소스가 조화를 이룹니다. 비건 고객도 즐길 수 있는 건강한 메뉴입니다. 따뜻한 바게트와 함께 제공됩니다.')

# %%
# VectorDB 저장 및 VectorStore 생성
from langchain_qdrant import QdrantVectorStore
from langchain_openai import OpenAIEmbeddings
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams
from dotenv import load_dotenv

load_dotenv()

COLLECTION_NAME = "restaurant_menu"
VECTOR_SIZE = 1536  # OpenAIEmbeddings의 벡터 크기

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

client = QdrantClient(host="localhost", port=6333)
if client.collection_exists(COLLECTION_NAME):
    client.delete_collection(COLLECTION_NAME)

# Collection 생성
client.create_collection(
    collection_name=COLLECTION_NAME,
    # 벡터 저장소에 대한 설정. - vector_config는 default이므로 이름을 안줘도 됨(default 로 잡힘) 이름을 줄 거면 {"이름":VectorParams()} 설정
    vectors_config=VectorParams(
        size=VECTOR_SIZE, 
        distance=Distance.COSINE
    )
)

vectorstore = QdrantVectorStore(
    client=client, # QdrantClient
    embedding=embeddings, # Embedding Model
    collection_name=COLLECTION_NAME # 연결할 Collection 지정.
)
ids = vectorstore.add_documents(menu_documents)
print(f"저장된 문서 개수: {len(ids)}")
##################################################
# Retriever 생성
##################################################
menu_retriever = vectorstore.as_retriever(
    search_kwargs={"k": 3}  # 검색할 결과 개수
)

from langchain_core.runnables import ConfigurableField
retriever = menu_retriever.configurable_fields(
    search_type=ConfigurableField(
        id="search_type"
    ),
    search_kwargs=ConfigurableField(
        id="search_kwargs"
    ),
)
# Out:
# 저장된 문서 개수: 15

# %%
query = "프랑스 음식을 추천해줘"
query = "소고기를 재료로 하는 음식은 뭐가 있어?"
result = retriever.invoke(query)

for doc in result:
    print(doc.metadata)
# Out:
# {'menu_name': '라따뚜이', 'price': 17000, 'ingredients': '가지, 호박, 파프리카, 토마토 소스, 올리브 오일', 'source': 'data/restaurant_menu.txt', '_id': 'a621a113-4e72-4a1a-a2a1-53cb2c0b43fe', '_collection_name': 'restaurant_menu'}
# {'menu_name': '부르기뇽 스튜', 'price': 28000, 'ingredients': '쇠고기, 적포도주, 양파, 당근, 베이컨', 'source': 'data/restaurant_menu.txt', '_id': 'daf94c65-bfbc-4cde-b89e-82aa8b644613', '_collection_name': 'restaurant_menu'}
# {'menu_name': '트러플 피자', 'price': 26000, 'ingredients': '트러플 오일, 모짜렐라 치즈, 얇은 피자 도우, 루꼴라', 'source': 'data/restaurant_menu.txt', '_id': '7d5a93bd-9971-47e2-a90b-cc4381e8905d', '_collection_name': 'restaurant_menu'}

# %%
#Retriever를 tool로 사용
#query를 입력 받아서 retriever로 검색해서 그 결과를 반환하는 tool을 직접 구현.

@tool
def search_menu(query: str) -> str:
    """ VectorStore(Vector Database)에 저장된 restaurant menu 를 검색하는 tool.
    이 도구는 query 에 맞는 식당 메뉴를 검색할 때 사용된다.
    
    Args : 
        query(str): vector db의 restaurant menu 에서 검색할 음식에 대한 query.
    Return:
        str: 검색 메뉴들에 대한 정보를 JSON 형식으로 반환한다.    
    """
    result_list = []
    docs = retriever.invoke(query)
    for doc in docs:
        result_list.append({"content":doc.page_content, "title":doc.metadata['menu_name'], "url":doc.metadata['source']})
    if result_list:
        reault = {"result": result_list}
    else:
        result = {"result":"검색된 메뉴가 없습니다."}
        
    return json.dump(result, ensure_ascii=False)

# %%
print(search_menu.name)
print(search_menu.description)
search_menu.args_schema.model_json_schema()
# Out:
# search_menu
# VectorStore(Vector Database)에 저장된 restaurant menu 를 검색하는 tool.
#    이 도구는 query 에 맞는 식당 메뉴를 검색할 때 사용된다.
#
#    Args :
#        query(str): vector db의 restaurant menu 에서 검색할 음식에 대한 query.
#    Return:
#        str: 검색 메뉴들에 대한 정보를 JSON 형식으로 반환한다.
# {'description': 'VectorStore(Vector Database)에 저장된 restaurant menu 를 검색하는 tool.\n이 도구는 query 에 맞는 식당 메뉴를 검색할 때 사용된다.\n\nArgs : \n    query(str): vector db의 restaurant menu 에서 검색할 음식에 대한 query.\nReturn:\n    str: 검색 메뉴들에 대한 정보를 JSON 형식으로 반환한다.    ',
#  'properties': {'query': {'title': 'Query', 'type': 'string'}},
#  'required': ['query'],
#  'title': 'search_menu',
#  'type': 'object'}

# %%
tool_model = ChatOpenAI(model="gpt-5-mini").bind_tools(tools=[search_menu])
res = tool_model.invoke("식당 메뉴 중 면 요리를 추천해줘.")

# %%
res.tool_calls
# Out:
# [{'name': 'search_menu',
#   'args': {'query': '면 요리'},
#   'id': 'call_4FS7FtBIsWDd6VaY9xmSP4B5',
#   'type': 'tool_call'}]

# %%
## Agent 를 구현
# 레스토랑 메뉴 추천, 설명 agent

# tool: tavily_search, search_wiki, search_menu ==> (검색 툴들.)

from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_openai import ChatOpenAI
from langchain_tavily import TavilyResearch
from dotenv import load_dotenv

load_dotenv()

tavily_search = TavilyResearch(max_results=5)
tools = [search_wiki, search_menu, tavily_search]

system_prompt = """
당신은 레스토랑 메뉴 정보와 일반적인 음식 관련 지식을 제공하는 AI 어시스턴트입니다. 
주요 목표는 사용자의 요청에 대한 정확한 정보를 제공하고 메뉴를 추천하는 것입니다.

주요 지침들(guidelines):
1.레스토랑의 메뉴관련 정보를 확인하려면 search_menu 도구를 사용하십시오. 이 도구는 레스토랑의 메뉴들의 가격, 음식의 특징들에 대한 정보를 제공합니다.
2.일반적인 음식 정보, 그 음식의 유래, 문화적 배경에 대한 정보는 search_wiki 도구를 사용하십시오. 이 도구는 wikipedia 에서 정보를 검색해서 제공합니다.
3.추가적인 웹 검색이 필요하거나 최신 정보를 얻고 싶을 때는 tavily_search 도구를 사용하십시오. 이 도구는 인터넷 검색을 통해 정보를 검색해서 제공합니다.
4.검색 결과를 기반으로 명확하고 간결한 답변을 제공하십시오.
5.요청 받은 질문이 모호하거나 필요한 정보가 부족한 경우 정중하게 설명을 요청하세요.
6.메뉴 정보를 제공할 때는 가격, 주재료, 특징 순으로 설명하세요
7.메뉴를 추천 할 때는 간단하게 추천 이유를 설명해주세요.
8.최종 응답은 챗봇과 같은 대화형 스타일을 유지하세요. 친근하고 매력적이며 자연스럽게 소통하되 전문성을 보이는 어조를 유지하세요.

-각 도구의 목적과 기능을 정확하게 이해하고 각 적절한 상황에서 사용하세요.
-각 도구들을 결합해서 사용자의 요청에 정확한 대답을 하세요.
-항상 가장 최신의 정확한 정보를 제공하기 위해 노력하세요.
"""

prompt = ChatPromptTemplate(
    [
        ("system", system_prompt),
        ("human", "{query}"),
        MessagesPlaceholder(variable_name="tool_messages", optional=True)
    ]
)
tool_model = ChatOpenAI(model="gpt-5.2").bind_tools(tools=tools)
tool_model_chain = prompt | tool_model

# %%
res = tool_model_chain.invoke({"query":"파스타 메뉴를 추천해주고 파스타의 유래나 역사를 알려줘."})

# %%
res.tool_calls
# Out:
# [{'name': 'search_menu',
#   'args': {'query': '파스타'},
#   'id': 'call_Gpe88i26nRIOUvbqE64eYlDo',
#   'type': 'tool_call'},
#  {'name': 'search_wiki',
#   'args': {'query': '파스타 기원 역사', 'max_results': 3},
#   'id': 'call_rTBAMsGJsjbUGv0hYkByZswb',
#   'type': 'tool_call'}]

# %%
#Agent 구현

@chain
def menu_recommand_agent(query:str) -> tuple[str, list]:
    """ 
    Agent 전체 흐름을 처리하는 Runnabel
    사용자 질문 (query)를 받아서 tool_model(search_menu, search_wiki, tavily_search) 과 tool을 이용해서 최종 응답을 반환한다.
    ReAct 구조로 구성. (ReAct Loop)
    """
    ai_message = tool_model_chain.invoke({"query":query}) # 반환: 1. 실제 응답, 2.tool calls 정보
    messages = [] # toolcall메세지, ToolMessage 들 저장 리스트(prompt tool_messages에 넣을 것)
    while ai_message.tool_calls: # 빈 리스트가 아니라면.
        #Tool 호출
        tool_messages = [] # 툴 호출 결과를 담을 리스트
        for tool_call in ai_message.tool_calls:
            # name = tool_call["name"]
            # if name=="search_wiki":
            #     tool_msg = search_wiki.invoke(tool_call)
            # elif name == "search_menu":
            #     tool_msg = search_menu.invoke(tool_call)
            # elif name == "tavily_search":
            #     tool_msg = tavily_search.invoke(tool_call)
            tool_msg = globals()[tool_call["name"]].invoke(tool_call) # 툴 명칭과 이름이 동일할 경우 globals 함수 사용 가능
            tool_messages.append(tool_msg)

        messages.extend([ai_message, *tool_messages])
        #tool 호출 결과를 넣어서 tool_model 에 다시 요청
        ai_message = tool_model_chain.invoke({"query":query, "tool_messages":messages})
    
    messages.append(ai_message) #마지막 응답 결과를 추가.
    return ai_message.content, messages #AIMessage

# %%
d = globals() # 전역 변수로 등록된 모든 변수, 함수들을 dictionary 제공. key : "이름", value: 변수/함수/클래스
d.keys()
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__vsc_ipynb_file__', '_i', '_ii', '_iii', '_i1', 'load_dotenv', 'TavilySearch', '_1', '_i2', 'ChatOpenAI', 'ChatMessagePromptTemplate', 'MessagesPlaceholder', 'chain', 'date', '_2', '_i3', '_i4', 'tavily_search', 'model', 'tool_model', 'system_message', 'today', '_i5', 'ChatPromptTemplate', '_5', '_i6', 'prompt', 'tool_model_chain', '_i7', '_i8', '_i9', '_i10', '_i11', '_11', '_i12', 'websearch_agent', '_i13', 'result', '_i14', '_14', '_i15', 'result2', '_i16', '_i17', '_17', '_i18', 'tool', 'plus', 'minus', 'multiyply', 'divide', '_i19', '_i20', '_i21', '_21', '_i22', '_22', '_i23', '_i24', 'BaseModel', 'Field', 'DivideParameterSchema', '_i25', '_25', '_i26', 'multiply', '_i27', 'calc_model', '_27', '_i28', 'WikipediaLoader', '_i29', 'json', 'wikipedia_search', '_i30', '_exit_code', '_i31', 'r', '_31', '_i32', '_32', '_i33', 'WikiSearchParameterSchema', 'searcy_wiki', '_i34', '_i35', '_i36', '_i37', 'search_wiki', '_i38', '_38', '_i39', 'res', '_i40', '_40', '_i41', 'os', 'menu_file_path', 'f', 'menu', '_i42', 'Document', 're', 'pprint', 'create_documents', 'menu_documents', '_42', '_i43', 'QdrantVectorStore', 'OpenAIEmbeddings', 'QdrantClient', 'Distance', 'VectorParams', 'COLLECTION_NAME', 'VECTOR_SIZE', 'embeddings', 'client', 'vectorstore', 'ids', 'menu_retriever', 'ConfigurableField', 'retriever', '_i44', 'query', 'doc', '_i45', '_i46', 'search_menu', '_i47', '_47', '_i48', '_i49', '_49', '_i50', 'TavilyResearch', 'tools', 'system_prompt', '_i51', '_i52', '_i53', '_i54', '_54', '_i55', '_55', '_i56', 'd'])

# %%
d['search_wiki']
# Out:
# StructuredTool(name='search_wiki', description='이 도구는 위키피디아에서 정보를 검색할 때 사용한다.\n사용자의 질문과 관련된 내용을 위키피디아에서 검색해 지정한 개수의 문서만큼 반환한다.\n일반적인 지식이나 백과사전 식 정보가 필요할 때 사용한다.', args_schema=<class '__main__.WikiSearchParameterSchema'>, func=<function convert_runnable_to_tool.<locals>.invoke_wrapper at 0x00000258168B0680>, coroutine=<function convert_runnable_to_tool.<locals>.ainvoke_wrapper at 0x00000258168B0540>)

# %%
def hello():
    print("안녕하세요")
hello()
globals()['hello']()
# Out:
# 안녕하세요
# 안녕하세요

# %%
res = menu_recommand_agent.invoke("디너로 먹을 파스타를 추천해주고, 파스타의 유래도 알려줘.")
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 res = menu_recommand_agent.invoke("디너로 먹을 파스타를 추천해주고, 파스타의 유래도 알려줘.")
#
# File c:\Users\USER\Documents\SKN21\10_langchain\.venv\Lib\site-packages\langchain_core\runnables\base.py:4871, in RunnableLambda.invoke(self, input, config, **kwargs)
#    4856 """Invoke this `Runnable` synchronously.
#    4857
#    4858 Args:
#    (...)   4868
#    4869 """
#    4870 if hasattr(self, "func"):
# -> 4871     return self._call_with_config(
#    4872         self._invoke,
#    4873         input,
#    4874         ensure_config(config),
#    4875         **kwargs,
#    4876     )
#    4877 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    4878 raise TypeError(msg)
#
# File c:\Users\USER\Documents\SKN21\10_langchain\.venv\Lib\site-packages\langchain_core\runnables\base.py:2058, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2054     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2055     with set_config_context(child_config) as context:
#    2056         output = cast(
#    2057             "Output",
# -> 2058             context.run(
#    2059                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2060                 func,
#    2061                 input_,
#    2062                 config,
#    2063                 run_manager,
#    2064                 **kwargs,
#    2065             ),
#    2066         )
#    2067 except BaseException as e:
#    2068     run_manager.on_chain_error(e)
#
# File c:\Users\USER\Documents\SKN21\10_langchain\.venv\Lib\site-packages\langchain_core\runnables\config.py:433, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     431 if run_manager is not None and accepts_run_manager(func):
#     432     kwargs["run_manager"] = run_manager
# --> 433 return func(input, **kwargs)
#
# File c:\Users\USER\Documents\SKN21\10_langchain\.venv\Lib\site-packages\langchain_core\runnables\base.py:4728, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    4726                 output = chunk
#    4727 else:
# -> 4728     output = call_func_with_variable_args(
#    4729         self.func, input_, config, run_manager, **kwargs
#    4730     )
#    4731 # If the output is a Runnable, invoke it
#    4732 if isinstance(output, Runnable):
#
# File c:\Users\USER\Documents\SKN21\10_langchain\.venv\Lib\site-packages\langchain_core\runnables\config.py:433, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     431 if run_manager is not None and accepts_run_manager(func):
#     432     kwargs["run_manager"] = run_manager
# --> 433 return func(input, **kwargs)
#
# Cell In[68], line 23, in menu_recommand_agent(query)
#      14 tool_messages = [] # 툴 호출 결과를 담을 리스트
#      15 for tool_call in ai_message.tool_calls:
#      16     # name = tool_call["name"]
#      17     # if name=="search_wiki":
#    (...)     21     # elif name == "tavily_search":
#      22     #     tool_msg = tavily_search.invoke(tool_call)
# ---> 23     tool_msg = globals()[tool_call["name"]].invoke(tool_call) # 툴 명칭과 이름이 동일할 경우 globals 함수 사용 가능
#      24     tool_messages.append(tool_msg)
#      26     tool_messages.append(tool_msg)
#
# File c:\Users\USER\Documents\SKN21\10_langchain\.venv\Lib\site-packages\langchain_core\tools\base.py:623, in BaseTool.invoke(self, input, config, **kwargs)
#     615 @override
#     616 def invoke(
#     617     self,
#    (...)    620     **kwargs: Any,
#     621 ) -> Any:
#     622     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 623     return self.run(tool_input, **kwargs)
#
# File c:\Users\USER\Documents\SKN21\10_langchain\.venv\Lib\site-packages\langchain_core\tools\base.py:950, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     948 if error_to_raise:
#     949     run_manager.on_tool_error(error_to_raise)
# --> 950     raise error_to_raise
#     951 output = _format_output(content, artifact, tool_call_id, self.name, status)
#     952 run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File c:\Users\USER\Documents\SKN21\10_langchain\.venv\Lib\site-packages\langchain_core\tools\base.py:916, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     914     if config_param := _get_runnable_config_param(self._run):
#     915         tool_kwargs |= {config_param: config}
# --> 916     response = context.run(self._run, *tool_args, **tool_kwargs)
#     917 if self.response_format == "content_and_artifact":
#     918     msg = (
#     919         "Since response_format='content_and_artifact' "
#     920         "a two-tuple of the message content and raw tool output is "
#     921         f"expected. Instead, generated response is of type: "
#     922         f"{type(response)}."
#     923     )
#
# File c:\Users\USER\Documents\SKN21\10_langchain\.venv\Lib\site-packages\langchain_core\tools\structured.py:93, in StructuredTool._run(self, config, run_manager, *args, **kwargs)
#      91     if config_param := _get_runnable_config_param(self.func):
#      92         kwargs[config_param] = config
# ---> 93     return self.func(*args, **kwargs)
#      94 msg = "StructuredTool does not support sync invocation."
#      95 raise NotImplementedError(msg)
#
# Cell In[46], line 22, in search_menu(query)
#      20 else:
#      21     result = {"result":"검색된 메뉴가 없습니다."}
# ---> 22 return json.dump(result, ensure_ascii=False)
#
# UnboundLocalError: cannot access local variable 'result' where it is not associated with a value

# %%
print(res[0])

# %%
res[1]

# %%
res[1][0].tool_calls

# %% [markdown]
# # create_agent() 를 이용한 Agent 구현
#
# - create_agent()
#   - Agent 생성 및 실행을 표준화, 단순화 하기 위헤 Langchain 1.0에서 도입된 함수
#   - 0.x 버전까지는 Agent 생성 함수는
#     1. model과 tool들을 넣어 Agent를 생성하고
#     2. 그것을 실행하는 Executor를 생성하는 방식으로
#   - 여러 단계를 거쳐야 했다.
#   - create_agent()는 이러한 단계를 1단계로 축약한 API이다.
#
# - create_agent 설계 철학
#     1. Agent를 구성하는 모든 실행단위는 Runnable 이다.
#     2. Agent도 Runnable 이다.
#     3. Agent는 하나의 표준 팩토리 함수(생성함수)로 통합한다.
#
# ## 주요 파라미터
# - https://reference.langchain.com/python/langchain/agents/
# - `model`: LLM 모델. Agent의 두뇌 역할을 하며 추론(Reasoning), 도구 선택, 최종 응답을 담당한다.
# - `tools`: Agent가 사용할 외부 도구모음.
# - `system_prompt`

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=ChatOpenAI(model="gpt-5-mini"),
    tools=tools,
    system_prompt=system_prompt #system prompt 에 추가될 내용
)

# %%
# agent 호출
res = agent.invoke(
    {
        "messages":[
            ("human", "파스타 메뉴를 추천해줘. 그리고 파스타의 유래에 대해 설명해줘.")
            ]
    }
)

# %%
res['messages']
# Out:
# [HumanMessage(content='파스타 메뉴를 추천해줘. 그리고 파스타의 유래에 대해 설명해줘.', additional_kwargs={}, response_metadata={}, id='87fd05cd-95dd-49cc-8f51-1a203d6ce7a1'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 288, 'prompt_tokens': 1176, 'total_tokens': 1464, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Csk5SXlqpTw8EvmhPtQLvmraTVGiy', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b731e-0681-7e01-8214-3f3bb4347a5c-0', tool_calls=[{'name': 'search_wiki', 'args': {'query': 'History of pasta origin', 'max_results': 5}, 'id': 'call_pwcFH15yV8WOvcc2EWbUN2MM', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1176, 'output_tokens': 288, 'total_tokens': 1464, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}}),
#  ToolMessage(content='{"result": [{"content": "헴프(hemp) 또는 산업용 헴프는 산업용 및 소비용으로 특별히 재배되는 칸나비스 사티바 재배품종 식물이다. 이 식물은 다양한 제품을 만드는 데 사용될 수 있다. 대나무와 함께 헴프는 지구상에서 가장 빠르게 자라는 식물 중 하나이다. 또한 50,000년 전 처음으로 사용 가능한 섬유로 방적된 식물 중 하나였다. 이는 종이, 밧줄, 직물, 옷, 생분해성 플라스틱, 도료, 단열재, 바이오 연료, 음식, 동물 사료를 포함한 다양한 상업 품목으로 정제될 수 있다.\\n화학형 I 대마와 헴프(유형 II, III, IV, V)는 모두 칸나비스 사티바이며 정신활성 성분인 테트라하이드로칸나비놀(THC)을 함유하고 있지만, 일반적으로 독특한 파이토케미컬 성분과 용도를 가진 별개의 재배품종 그룹을 나타낸다. 헴프는 일반적으로 총 THC 농도가 낮고, 칸나비디올(CBD) 농도가 높을 수 있으며, 이는 THC의 신경정신약물 효과를 잠재적으로 완화한다. 헴프의 합법성은 국가마다 크게 다르다. 일부 정부는 THC 농도를 규제하고 특히 낮은 THC 함량으로 재배된 헴프만 상업 생산을 허용한다.\\n\\n\\n== 어원 ==\\n\\n어원은 불확실하지만, 이 단어의 다양한 형태에 대한 공통적인 인도유럽조어 원천은 없는 것으로 보인다. 그리스어 용어 κάνναβις (kánnabis)는 가장 오래된 문증된 형태이며, 이전 스키타이어 또는 트라키아어에서 차용되었을 수 있다. 그 후 라틴어로, 그리고 별도로 슬라브족 언어로, 거기서부터 발트 3국 언어, 핀란드어, 게르만어로 차용된 것으로 보인다.\\n게르만어군에서는 그림의 법칙에 따라 첫 번째 게르만어 음운 변화에서 \\"k\\"가 \\"h\\"로 바뀌어 게르만조어 *hanapiz가 되었고, 그 후 고대 영어 형태인 hænep, henep으로 각색되었을 수 있다. 그러나 바버 (1991)는 \\"칸나비스\\"라는 이름의 확산이 이란 주변 남쪽에서 시작된 식물 사용의 더 최근 역사적 배경 때문이라고 주장했는데, 이는 비-THC 헴프 품종이 더 오래되고 선사시대부터 존재했기 때문이다. 또 다른 가능한 기원으로는 아시리아어 qunnabu가 있으며, 이는 기원전 1천년에 기름, 섬유, 약품의 원료를 지칭하는 이름이었다.\\n다른 게르만어군 언어에서 헴프의 동계어로는 네덜란드어 hennep, 덴마크어 및 노르웨이어 hamp, 사터랜드 프리슬란드어 Hoamp, 독일어 Hanf, 아이슬란드어 hampur, 스웨덴어 hampa가 있다. 이 언어들에서 \\"hemp\\"는 산업용 섬유 헴프 또는 마약성 대마초 품종을 지칭할 수 있다.\\n\\n\\n== 용도 ==\\n\\n헴프는 광범위한 상업 및 산업 제품을 만드는 데 사용된다. 헴프 씨앗은 직접 식용으로 섭취되며, 요리용, 영양 보충제, 화장품, 페인트 및 광택제의 건조유로 사용되는 기름으로도 압착된다. 기름 추출의 부산물인 헴프 씨앗박은 유리한 단백질 및 지방산 프로필로 인해 가금류, 돼지, 소, 어류 및 반려동물 사료용으로 점차 평가되고 있다.\\n인피 섬유는 직물 및 혼방 직물, 가구, 특수지에 적용된다. 또한 헴프크리트, 섬유 강화 단열 패널, 가구 및 자동차 부품용 바이오 복합 재료와 같은 건축 자재용 복합 재료로 가공된다. 헴프 섬유는 기타, 앰프를 포함한 악기 및 종이용 펄프와 생분해성 포장재와 같은 특수 제품에도 사용된다.\\n내부 목질 핵(허드 또는 쉬브)은 동물 침대, 정원 멀치, 깔짚, 경량 건축 블록 및 파티클 보드의 구성 요소로 사용된다. 헴프 오일 및 추출물은 칸나비디올(CBD)과 같은 비중독성 칸나비노이드 제품, 식이 보충제, 화장품 및 웰니스 제형에도 사용된다.\\n\\n\\n=== 음식 ===\\n\\n헴프 씨앗은 생으로 먹거나, 헴프 가루로 갈거나, 발아시키거나, 건조 발아 가루로 만들 수 있다. 헴프 씨앗은 또한 베이킹이나 삼씨밀크와 허브차와 같은 음료에 사용되는 슬러리로 만들 수 있다. 삼씨기름은 씨앗에서 압착 추출되며 불포화 지방산 함량이 높다.\\
 1회 제공량은 약 3테이블스푼인 30g이다.\\n헴프는 글루텐 함량이 4.78ppm으로 낮아 글루텐 프리(<20ppm) 식품 재료로 주목받고 있다.\\n헴프 씨앗의 풍부한 영양 성분에도 불구하고, 씨앗에는 피트산, 트립신 억제제, 탄닌과 같은 영양 저해 물질이 통계적으로 유의미한 농도로 포함되어 있다.\\n\\n\\n==== 저장 ====\\n삼씨기름은 적절하게 보관하지 않으면 단기간 내에 산화되어 산패된다. 어둡고 밀폐된 용기에 넣어 냉장 보관하면 유통 기한이 연장된다. 빛과 열 모두 헴프 오일을 변질시킬 수 있다.\\n\\n\\n=== 섬유 ===\\n헴프 섬유는 역사적으로 광범위하게 사용되었으며, 신세계에 도입된 직후 생산량이 최고조에 달했다. 수세기 동안 밧줄에서 직물, 산업용 재료에 이르기까지 다양한 품목이 헴프 섬유로 만들어졌다. 헴프는 또한 돛 캔버스를 만드는 데 흔히 사용되었다. \\"캔버스\\"라는 단어는 칸나비스(cannabis)에서 유래했다. 순수한 헴프는 아마포와 비슷한 질감을 가진다. 다양한 제품에  ...
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 359, 'prompt_tokens': 3934, 'total_tokens': 4293, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Csk5dErodaZFubRXHl7OVqdtkfH5x', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b731e-30b4-7051-bf40-806435f0791f-0', tool_calls=[{'name': 'search_wiki', 'args': {'query': 'history of pasta origin pasta 유래 파스타 기원', 'max_results': 5}, 'id': 'call_VUSE4kuf6FdHZrc3XDwBkkk4', 'type': 'tool_call'}], usage_metadata={'input_tokens': 3934, 'output_tokens': 359, 'total_tokens': 4293, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}}),
#  ToolMessage(content='{"result": "검색결과가 없습니다."}', name='search_wiki', id='d2f236c8-8d49-4389-8bf8-7da99cd72a8f', tool_call_id='call_VUSE4kuf6FdHZrc3XDwBkkk4'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 223, 'prompt_tokens': 3990, 'total_tokens': 4213, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 3712}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Csk5k0FNaJ3LqX7z8OAqLPB6BM139', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b731e-4b5c-7300-9757-2407f37a2f65-0', tool_calls=[{'name': 'search_wiki', 'args': {'query': 'Pasta history', 'max_results': 5}, 'id': 'call_0CbLbzyOE3MKzSmLmcELy4ma', 'type': 'tool_call'}], usage_metadata={'input_tokens': 3990, 'output_tokens': 223, 'total_tokens': 4213, 'input_token_details': {'audio': 0, 'cache_read': 3712}, 'output_token_details': {'audio': 0, 'reasoning': 192}}),
#  ToolMessage(content='{"result": [{"content": "파스타(이탈리아어: pasta)는 이탈리아의 밀 식품이다. 듀럼밀 세몰라에 물을 섞거나 밀가루에 달걀을 섞어 부풀리지 않고 반대기를 지어서 국수 등의 형태로 만든 음식이며, 삶거나 구워 먹는다. 이탈리아의 주식이며, 국민 음식 가운데 하나로 여겨진다.\\n\\n\\n== 이름 ==\\n이탈리아어 \\"파스타(pasta)\\"는 \\"반죽, 페이스트\\"를 뜻하는 명사이다.\\n\\n\\n== 역사 ==\\n\\n2세기경 그리스의 의사 갈레노스의 저서에는 밀가루와 물을 함께 혼합해서 만든 itrion이라는 말이 언급되어 있다. 예루살렘 탈무드에 기록된 itrium은 삶은 반죽 종류로, 팔레스타인에서 3세기부터 5세기까지 먹었으며, 9세기의 시리아의 의사이자 사서학자인 Isho bar Ali가 편찬한 사전에는 아라비아 어원을 가지고 있으며, 세몰리나로 만들어 말려서 요리하는 끈같은 모양의 itriyya에 대해서 설명하고 있다. 무함마드 알 이드리시의 지리학 저서에는 1154년 시칠리아 로저 2세 시대의 자료를 편찬하면서 노르만 시칠리아에서 생산하고 수출하는 이트리야 (itriyya)에 대해 언급하고 있다.\\n\\n말단의 서부에는 Trabia라고 불리는 즐거운 곳이 있다. 이곳의 영원히 흐르는 강은 많은 밀을 흘러갈 수 있게 한다. 이 지방의 거대한 건물에서는 사람들이 칼라브리아, 무슬림과 기독교 국가에 보낼 막대한 양의 이트리야를 만든다. 매우 많은 양이 배로 수송된다.\\n이트리야는 이탈리아에서 trie로 알려졌는데 이 말은 tagliatelli와 같이 길다란 끈을 의미하는 말이었다. 이트리야의 형태 중 하나로 오랜 역사를 지닌 laganum (복수형 lagana)은 라틴어로 얇은 면 반죽을 뜻하며, 이탈리아에서는 \\"라사냐\\"로 알려졌다.\\n기원전 1세기 호라티우스의 저서에는 lagana를 기름으로 튀긴 얇은 반죽이며, 일상식이었다고 쓰고 있다. 2세기 때 나우크라티스의 아테나이오스의 저서에는 1세기 때 쓰여진 티아나의 크리시포스의 lagana 요리법이 나와있다. 이 요리법에서는 으깬 상추액과 밀가루로 만든 얇은 면 반죽에 양념을 한 후 기름에 바싹 튀기는 방법을 쓰고 있다. 5세기 초에 쓰여진 요리책에는 고기가 들어간 얇은 층으로 된 면 반죽이 들어가는 요리 lagana에 대해서 설명하고 있는데, 오늘날의 음식인 라사냐의 원형이라고 볼 수 있다. 그러나 이 반죽을 요리하는 과정은 지금의 드라이 파스타나 프레시 파스타와는 많이 다르다. 이탈리아 시대에서 파스타에 대한 구체적인 자료가 등장한 때는 13~14세기이다.\\n한편, 중국에서도 기원전 2000년부터 잡곡으로 만든 국수를 먹어왔지만, 듀럼밀은 후세까지 알려지지 않았다. 마르코 폴로가 중국에서 파스타를 들여왔다는 가설은 미국의 잡지 〈마카로니 저널〉에서 나왔다. 이 잡지는 미국의 파스타 판매를 촉진하기 위해 식품 회사 협회가 출간한 것이었다. 마르코 폴로가 동방견문록에서 \\"라가나\\" (lagana)와 유사한 음식에 대해서 묘사하고 있지만, 이것은 그가 잘 알고 있던 단어를 사용한 것일뿐이다. 국제 마카로니 제조업자 협회에 따르면 오늘날의 듀럼밀로 만들어진 파스타는 아랍인이 시칠리아를 지배하였을 때 들어온 것이다.\\n파스타는 그리스 신화에서 헤파이스토스가 파스타 제조 기구를 발명했다는 설과 기원전 5세기경에 이탈리아 중서부의 고대국가인 에트루리아족이 만들어 먹었다는 설 등 그 기원에 대해 아직까지 여러 가지 이설이 있다.\\n\\n\\n== 종류 ==\\n\\n\\n=== 재료와 제조 방식 ===\\n\\n\\n==== 건파스타 ====\\n\\n건파스타(乾pasta, 이탈리아어: pasta secca 파스타 세카[*]) 단순한 튜브 형태에서부터 나비넥타이 모양에 이르기까지 약 350종이 존재한다. 덥고 건조한 날씨에도 오랫동안 보관할 수 있어서 주로 이탈리아 남부에서 사용한다. 건파스타는 \\"듀럼밀\\"로도 불리는 경질밀(grano duro) 세몰라와 물을 사용하여 만든다. 듀럼밀을 갈아 만든 거칠고 날카로운 입자 형태의 황갈색 세몰라는 파스타를 만드는데 적합하다. 이는 듀럼밀이 글루텐을 많이 함유하고 있어 녹말 입자가 쉽게 파괴되기 어렵고 수분 흡수를 조절하며, 지나치게 부풀어 오르지 않아 파스타의 형태를 단단하게 유지하기 때문이다 대부분의 건파스타는 압출성형 공법을 통해 상업적으로 생산되지만, 집에서도 만들 수 있다. 재료는 같은 재료를 사용하여 만들어도 이탈리아의 건파스타는 일반적으로 다른 곳의 건파스타보다 훨씬 우수한데 그 이유는 특유의 압출과 건조 방식에 있다. 건파스타는 모양이 복잡할수록 소스를 잘 붙잡아두는데, 봉긋하게 솟아 있거나 움푹 팬 모양은 파스타를 구리 틀에서 짜내는 압출과정에서 만들어진다. 구리 틀은 값도 비싸고 금방 못 쓰게 되는 단점이 있지만, 이탈리아에서는 최고의 건파스타를 만들기 위해 구리 틀을 일반적으로 사용한다. 반면 철로 만든 틀을 사용하는 다른 나라들의 파스타는 면이 너무 매끈해 소스와 잘 어우러지지 못하는 경우가 많다. 건파스타를 만들 때는 온도와 시간도 매우 중요한데, 대량 생산되는 파스타는 짧은 시간에 너무 높은 온도에서 건조하기 때문에 이탈리아의 전통 파스타보다 질이 떨어진다.\\n\\n\\n==== 생파스타 ====\\n\\n생파스타(生pasta, 이탈리아어: pasta fresca 파스타 프레스카[*])의 경우 전통적으로 수작업을 통해 만들어지며, 때때로 간단한 기계(파스타기)의 도움을 받기도 한다. 식료품 가게에서 구입하는 생파스타는 기계에 의해 상업적으로 생산된다. 연질밀(grano tenero) 가루와 달걀에 물이나 올리브 오일을 더해 만드는 생파스타는 토양이 비옥하고 달걀이 풍부한 이탈리아 북부 지방에서 주로 사용된다. 달걀이 들어간 파스타를 \\"달걀 파스타(pasta all\'uovo)\\"라 부르기도 한다. 생파스타를 만드는 반죽의 반대기는 \\"스폴리아\\"라 불린다. 건파스타가 주를 이루는 남부 지방에서는 특별한 날에 라비올리나 칸넬로니처럼 소를 넣은 생파스타를 만들어 먹는다. 일반적으로 그날 만든 생파스타 요리를 대접하는 것은 손님에 대한 정성과 그 집의 뛰어난 요리 솜씨를 보여주는 것이라 여겨진다. 그러나 생파스타가 건파스타보다 본질적으로 더 우수한 것은 아니다. 단지 어디에 쓰이냐에 따라 면이 달라질 뿐이다. 즉 어떤 파스타는 생파스타로만, 어떤 파스타는 건파스타로만 만들고 둘 다 가능한 것도 있다. 생파스타는 에밀리아로마냐 지방의 것을 최고로 친다. 이곳의 생파스타는 보통 크림 소스나 버터와 샐비어로 만든 간단한 소스와 함께 먹고, 여름철에는 가벼운 토마토 소스에 먹기도 한다.\\n\\n\\n=== 모양 ===\\n건파스타와  생파스타 모두 다양한 모양과 변형을 가지고 있다. 파스타의 구체적인 형태는 310개로, 기록된 파스타의 이름은 1,300개가 넘는다. 이탈리아에서 일부 파스타의 모양이나 종류는 지역에 따라 다양하다. 예를 들어 파스타 모양인 카바텔리는 마을과 지역에 따라 부르는 이름이 달라 총 28개의 이름을 가지고 있는 것으로 유명하다. 파스타의 일반적인 모양은 긴 형태, 짧은 형태, 튜브, 납작한 형태, 시트, 수프를 위한 미니어처 형태, 속을 채우는 형태, 지역 특산품, 또는 장식품 등이 포함된다.\\n\\n\\n==== 긴 파스타 ====\\n\\n\\n==== 둥지 모양 파스타 ====\\n\\n\\n==== 구멍 뚫린 파스타 ====\\n\\n\\n==== 짧은 파스타 ====\\n\\n\\n==== 수프용 파스타 ====\\n\\n\\n==== 소를 넣은 파스타 ====\\n\\n\\n== 요리 ==\\n이탈리아 요리에서 파스타는 물에 삶은 다음 소스를 곁들여 내는 파스타 아시우타(이탈리아어: pasta asciutta), 수프 그릇에 국물과 함께 담아 내는 파스타 인 브로도(이탈리아어: pasta in brodo), 오븐에 구워 조리하는 파스타 알 포르노(이탈리아어: pasta al forno) 등의 방식으로 조리한다. 파스타 샐러드를 먹기도 한다.\\n건파스타는 소스를 얹었을  ...
#  AIMessage(content='좋아요 — 몇 가지 인기 있는 파스타 메뉴를 추천해드릴게요. 먼저 간단히 원하시는 스타일(가벼운/진한/해산물/고기/채식 등)이나 예산이 있으면 더 정확히 추천해 드릴 수 있어요. 일단 일반적으로 많은 분들이 좋아하는 대표 메뉴 5가지를 가격대(한국 기준 예상), 주재료, 특징 순으로 정리했습니다.\n\n1) 카르보나라 (Carbonara)\n- 가격: 약 12,000–18,000원\n- 주재료: 스파게티(또는 리가토니), 판체타(또는 베이컨), 계란, 페코리노 또는 파르미지아노 치즈, 흑후추\n- 특징: 크리미하고 고소한 맛. 소스에 생계란을 사용해 부드러운 질감이 핵심. 진한 맛을 좋아하시면 추천.\n- 추천 이유: 부담스럽게 진한 풍미와 단백질이 있어 식사로 든든함.\n\n2) 토마토 소스 파스타(마리나라/폼도로)\n- 가격: 약 9,000–15,000원\n- 주재료: 파스타 면, 토마토 소스(산마르자노 토마토 등), 마늘, 올리브오일, 바질\n- 특징: 깔끔하고 상큼한 토마토 풍미. 가볍게 먹기 좋음.\n- 추천 이유: 무난하면서도 깔끔해 처음 파스타 드시는 분이나 가벼운 식사로 좋음.\n\n3) 페스토 제노베제 (Pesto Genovese)\n- 가격: 약 12,000–18,000원\n- 주재료: 바질, 잣(또는 호두), 올리브오일, 파르미지아노/페코리노, 마늘, 페투치네/스파게티\n- 특징: 허브향 · 견과류의 고소함이 강한 비냉(생) 소스. 상큼하고 향긋함.\n- 추천 이유: 채식 계열이나 신선한 허브향을 좋아하시는 분께 추천.\n\n4) 알리오 올리오 페페론치노 (Aglio e Olio)\n- 가격: 약 9,000–14,000원\n- 주재료: 스파게티, 올리브오일, 마늘, 페페론치노(고추), 파슬리\n- 특징: 매우 심플하지만 마늘과 올리브오일의 풍미가 강조된 깔끔하고 가벼운 파스타.\n- 추천 이유: 소스가 가벼워 면 본연의 식감과 맛을 즐기고 싶을 때 적합. 속 편한 식사로도 좋아요.\n\n5) 볼로네제(라구) / 아마트리차나\n- 가격: 약 11,000–18,000원\n- 주재료(볼로네제): 다진 소고기, 토마토, 양파, 당근, 셀러리, 레드와인, 파스타(탈리아텔레 등)\n- 특징(볼로네제): 고기 풍미가 진하고 소스가 걸쭉해 넓적한 면과 잘 어울림.  \n- 가격/주재료(아마트리차나): 약 12,000–18,000원 / 구안찰레(또는 판체타), 토마토, 페코리노, 후추  \n- 특징(아마트리차나): 짭짤한 돼지고기와 토마토의 조화, 풍미 강함.\n- 추천 이유: 고기 소스를 좋아하시면 만족도가 높음. 든든한 한 끼로 적합.\n\n파스타 유래(간단 정리)\n- 고대·중세 문헌에 등장: “파스타”의 원형으로 볼 수 있는 반죽 관련 언급은 고대 그리스·로마 문헌(예: laganum — 얇은 반죽, 라자냐의 원형)에서 찾을 수 있고, 중세 아랍·지중해 문헌에는 itriyya(itria, 말린 국수류)를 뜻하는 기록이 있습니다.\n- 아랍권과 시칠리아 영향: 특히 마른 듀럼밀 세몰리나로 만든 건파스타(말려서 보관 가능한 형태)는 중세에 아랍 상인·정복자들을 통해 시칠리아 등지에 전파된 것으로 알려져 있습니다. 듀럼밀 기반의 마른 파스타는 건조 보관과 장거리 유통에 유리했습니다.\n- 마르코 폴로 신화는 과장: 마르코 폴로가 중국에서 이탈리아로 국수를 가져왔다는 이야기는 근대에 유포된 설로, 역사적 근거가 약하다는 것이 정설입니다. 중국의 국수 전통과 지중해의 파스타 전통은 별개로 오래된 역사를 가집니다.\n- 오늘날의 분류: 전통적으로 건파스타(듀럼밀·세몰라 사용)와 생파스타(달걀을 넣는 북이탈리아식)가 주요 분류이며, 형태·소스에 따라 수백 종의 파스타 요리가 발전했습니다.\n\n더 도와드릴까요?\n- 원하시면: 예산/취향을 알려주시면 맞춤 추천 해드릴게요.\n- 특정 식당의 메뉴와 가격을 확인해 드리려면 식당 이름 알려주시면 search_menu로 메뉴·가격 확인해 드리겠습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2144, 'prompt_tokens': 14432, 'total_tokens': 16576, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 896, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 3712}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Csk5zzezDEgjU7rnqT2l6MyWj2RQp', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b731e-8417-7fd2-9b3e-15960b99eee4-0', usage_metadata={'input_tokens': 14432, 'output_tokens': 2144, 'total_tokens': 16576, 'input_token_details': {'audio': 0, 'cache_read': 3712}, 'output_token_details': {'audio': 0, 'reasoning': 896}})]

# %%
print(res['messages'][-1].content)
# Out:
# 좋아요 — 몇 가지 인기 있는 파스타 메뉴를 추천해드릴게요. 먼저 간단히 원하시는 스타일(가벼운/진한/해산물/고기/채식 등)이나 예산이 있으면 더 정확히 추천해 드릴 수 있어요. 일단 일반적으로 많은 분들이 좋아하는 대표 메뉴 5가지를 가격대(한국 기준 예상), 주재료, 특징 순으로 정리했습니다.
#
# 1) 카르보나라 (Carbonara)
# - 가격: 약 12,000–18,000원
# - 주재료: 스파게티(또는 리가토니), 판체타(또는 베이컨), 계란, 페코리노 또는 파르미지아노 치즈, 흑후추
# - 특징: 크리미하고 고소한 맛. 소스에 생계란을 사용해 부드러운 질감이 핵심. 진한 맛을 좋아하시면 추천.
# - 추천 이유: 부담스럽게 진한 풍미와 단백질이 있어 식사로 든든함.
#
# 2) 토마토 소스 파스타(마리나라/폼도로)
# - 가격: 약 9,000–15,000원
# - 주재료: 파스타 면, 토마토 소스(산마르자노 토마토 등), 마늘, 올리브오일, 바질
# - 특징: 깔끔하고 상큼한 토마토 풍미. 가볍게 먹기 좋음.
# - 추천 이유: 무난하면서도 깔끔해 처음 파스타 드시는 분이나 가벼운 식사로 좋음.
#
# 3) 페스토 제노베제 (Pesto Genovese)
# - 가격: 약 12,000–18,000원
# - 주재료: 바질, 잣(또는 호두), 올리브오일, 파르미지아노/페코리노, 마늘, 페투치네/스파게티
# - 특징: 허브향 · 견과류의 고소함이 강한 비냉(생) 소스. 상큼하고 향긋함.
# - 추천 이유: 채식 계열이나 신선한 허브향을 좋아하시는 분께 추천.
#
# 4) 알리오 올리오 페페론치노 (Aglio e Olio)
# - 가격: 약 9,000–14,000원
# - 주재료: 스파게티, 올리브오일, 마늘, 페페론치노(고추), 파슬리
# - 특징: 매우 심플하지만 마늘과 올리브오일의 풍미가 강조된 깔끔하고 가벼운 파스타.
# - 추천 이유: 소스가 가벼워 면 본연의 식감과 맛을 즐기고 싶을 때 적합. 속 편한 식사로도 좋아요.
#
# 5) 볼로네제(라구) / 아마트리차나
# - 가격: 약 11,000–18,000원
# - 주재료(볼로네제): 다진 소고기, 토마토, 양파, 당근, 셀러리, 레드와인, 파스타(탈리아텔레 등)
# - 특징(볼로네제): 고기 풍미가 진하고 소스가 걸쭉해 넓적한 면과 잘 어울림.
# - 가격/주재료(아마트리차나): 약 12,000–18,000원 / 구안찰레(또는 판체타), 토마토, 페코리노, 후추
# - 특징(아마트리차나): 짭짤한 돼지고기와 토마토의 조화, 풍미 강함.
# - 추천 이유: 고기 소스를 좋아하시면 만족도가 높음. 든든한 한 끼로 적합.
#
# 파스타 유래(간단 정리)
# - 고대·중세 문헌에 등장: “파스타”의 원형으로 볼 수 있는 반죽 관련 언급은 고대 그리스·로마 문헌(예: laganum — 얇은 반죽, 라자냐의 원형)에서 찾을 수 있고, 중세 아랍·지중해 문헌에는 itriyya(itria, 말린 국수류)를 뜻하는 기록이 있습니다.
# - 아랍권과 시칠리아 영향: 특히 마른 듀럼밀 세몰리나로 만든 건파스타(말려서 보관 가능한 형태)는 중세에 아랍 상인·정복자들을 통해 시칠리아 등지에 전파된 것으로 알려져 있습니다. 듀럼밀 기반의 마른 파스타는 건조 보관과 장거리 유통에 유리했습니다.
# - 마르코 폴로 신화는 과장: 마르코 폴로가 중국에서 이탈리아로 국수를 가져왔다는 이야기는 근대에 유포된 설로, 역사적 근거가 약하다는 것이 정설입니다. 중국의 국수 전통과 지중해의 파스타 전통은 별개로 오래된 역사를 가집니다.
# - 오늘날의 분류: 전통적으로 건파스타(듀럼밀·세몰라 사용)와 생파스타(달걀을 넣는 북이탈리아식)가 주요 분류이며, 형태·소스에 따라 수백 종의 파스타 요리가 발전했습니다.
#
# 더 도와드릴까요?
# - 원하시면: 예산/취향을 알려주시면 맞춤 추천 해드릴게요.
# - 특정 식당의 메뉴와 가격을 확인해 드리려면 식당 이름 알려주시면 search_menu로 메뉴·가격 확인해 드리겠습니다.

# %% [markdown]
# # LangChain에서 MCP 연동
#
# ## MCP란
#
# - **MCP**(**Model Context Protocol**)는 Anthropic이 주도하여 2024년 말에 발표한 개방형 표준으로, LLM 애플리케이션이 외부 데이터 소스나 도구에 접근하는 방식을 표준화 하는 프로토콜이다.
#   - Agent가 이용할 수 있는 tool을 구현하는 방법은 framework 마다 다르기 때문에 서로 호환 되지 않는 문제가 있다.
#   - MCP는 이런 문제를 해결하기 위해 만든 표준 프로토콜이다.
#
# ## MCP 아키텍처 구성 요소
# - **MCP 호스트**
#   -  AI 애플리케이션(예: LLM 채팅 애플리케이션)으로 MCP 클라이언트를 통해 여러 서버에 연결한다.
#
# - **MCP 클라이언트**
#   -  각 MCP 서버와의 연결을 유지하는 구성요소로, 서버로부터 도구/리소스/프롬프트를 가져와 LLM 모델에게 전달한다.
#
# - **MCP 서버**
#   -  외부 데이터 소스나 Tool들을 제공하는 프로그램이다. 서버는 도구, 리소스, 프롬프트를 노출하고 클라이언트와 JSON‑RPC 2.0 메시지로 통신한다.
#   -  MCP는 서버 클라이언트 간의 **로컬 프로세스 간 통신을 위한 STDIO**와 **원격 서버 접속을 위한 Streamable HTTP** 두 가지 전송 방식을 지원한다
#   -  **MCP 서버가 제공하는 것**
#      -  **도구**(**Tools**): LLM이 호출할 수 있는 함수형 작업이다. 예를 들어 “queryDatabase”, “sendEmail” 등이 있으며 각 도구는 이름, 설명, 입력 스키마를 포함한다.
#      -  **리소스**(**Resources**): 읽기 전용 데이터 소스로, 검색 색인·파일시스템·데이터베이스 등에서 컨텍스트를 제공한다.
#      -  **프롬프트**(**Prompts**): LLM 프롬프트 템플릿이나 예시를 서버에서 제공해 AI 모델의 질의를 돕는다.
#
#
# ## 사용 가능한 MCP 툴 찾기
#
# - MCP 생태계에는 수천 개의 툴 서버가 이미 공개되어 있으며, 원하는 기능의 툴을 검색하여 사용할 수 있다.
# - MCP 검색 및 서비스 사이트
#   - [PulseMCP](https://pulsemcp.com)
#   - [MCP 마켓](https://mcpmarket.com/ko)
#   - [MCP Servers](https://mcp.so/)
#   - [smithery](https://smithery.ai/servers)

# %% [markdown]
# ## LangChain에서 MCP 툴 연동하기
# - Node.js 를 설치
# - LangChain에서 MCP 서버와 연동하기 위해서는 Adapter lib 설치가 필요하다.
#   - `pip install langchain-mcp-adapters`
#
# ###  MultiServerMCPClient
# - **MCP 클라이언트 객체**로, LangChain에서 **하나 이상의 MCP 서버를 연결하고 Tool 목록을 가져오기 위해 사용**한다.
#     - 여러 개의 MCP 서버를 **동시에 등록하고 연결**할 수 있다.
#     - 서버 설정들을 **하나의 딕셔너리**(**Dictionary**)로 묶어 전달하며, **각 개별 서버 역시 Dictionary로 설정**한다.
#     - MCP 클라이언트에 등록된 모든 서버는 이후 `get_tools()` 호출을 통해 서버가 제공하는 tool들을 **LangChain의 Tool 객체로 자동 변환해 Agent가 호출**(**사용**)할 수있게 한다.
#
# #### 개별 서버 설정 Key 정의
# - **`dict[str: 서버 별칭, dict: 서버 설정]`**
#
# | 설정 Key        | 의미                                                                  | 사용 예                            |
# | --------------- | --------------------------------------------------------------------- | ---------------------------------- |
# | **`transport`** | 서버와 통신하는 방식                                                  | `"stdio"` 또는 `"streamable-http"` |
# | **`command`**   | MCP 서버를 실행할 프로그램(프로세스)                                  | `"python"` 또는 `"npx"`            |
# | **`args`**      | command에 전달할 세부 실행 인자를 **리스트(List)**에 문자열로 순서대로 배치 | `["-m", "mcp_server_time"]`  |
#
# - **transport 값에 따른 동작 구분**
#     - `"stdio"`: 로컬에서 실행되는 서버 연결
#     - `"streamable-http"`: 원격 MCP 서버(서비스형) 연결
#
#     ```json
#         {
#             "time": {
#                 "transport": "stdio",
#                 "command": "python",
#                 "args": ["-m", "mcp_server_time"]
#             }
#
#             "github": {
#                 "transport": "streamable-http",
#                 "url": "https://server.smithery.ai/github",
#             }
#         }
#     ```
#
# #### command + args 와 실행 명령어 관계
#
# | 실제 실행 명령                    | 설정으로 표현되는 방식                                             |
# | --------------------------- | -------------------------------------------------------- |
# | `python -m mcp_server_time` | `"command": "python", "args": ["-m", "mcp_server_time"]` |
# | `npx -y @org/server`        | `"command": "npx", "args": ["-y", "@org/server"]`        |
#
# * **command는 실행 프로그램**, args는 **명령 뒤에 붙는 옵션을 순서 그대로 리스트에 나열**한다.

# %%
# uv pip install mcp_server_time
# python -m mcp_server_time - >mcp 서버 실행.

# %%
# jupyter lab 에서 비동기 처리를 위해서 실행.

import nest_asyncio

nest_asyncio.apply()

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient
from langchain_openai import ChatOpenAI

from langchain.agents import create_agent
from dotenv import load_dotenv
import asyncio

load_dotenv()
# Out:
# True

# %%
# %%writefile mcp_exam.py
from langchain_mcp_adapters.client import MultiServerMCPClient
from langchain_openai import ChatOpenAI

from langchain.agents import create_agent
from dotenv import load_dotenv
import asyncio
import os

load_dotenv()

async def main():
    # 1. MCP Client 생성: 연결할 서버 정보를 제공(실행)
    client = MultiServerMCPClient(
        {
            "time": {
                "transport":"stdio", # 통신방식
                "command":"python",
                "args":["-m","mcp_server_time"] # command + args 실행 : python -m mcp_server_time 서버를 실행하고 연결
            },
            "filesystem": {
                "transport":"stdio",
                "command": "npx",
                "args": [
                    "-y",
                    "@modelcontextprotocol/server-filesystem",
                    os.getcwd(), # filesystem이 사용할 수 있는 디렉토리 경로들을 지정.
                    r"c:\temp"
                     ]
            }
        }       
    )
    #MCP Client로 부터 tool 들을 가져오기
    tools = await client.get_tools()

    
    #tools : list[structuredTool - Langchain Tool 타입] - ㅡMCP 서버의 툴들을 langchain 에서 사용할 수 있게 만들어서 반환

    agent = create_agent(
        model=ChatOpenAI(model="gpt-5.2"),
        tools=tools,
        system_prompt=""" 당신은 AI Assistenat입니다. 필요한 경우 등록된 도구들을 이용해 질문에 답하세요. 답변은 한국어로 하세요."""
    )
    print(">>>>>>> 종료하려면 !quit을 입력하세요<<<<<<<")
    while True:
        query = input("질문:")
        if query == "!quit":
            print(">>>종료<<<")
        res = await agent.ainvoke({
            "messages":[
                ("human", query)
            ]
        })
        print(res['messages'][-1].content)




if __name__ == "__main__":
    asyncio.run(main())
# Out:
# Overwriting mcp_exam.py
